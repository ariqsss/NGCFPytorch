# %%
import numpy as np
import random as rd
import scipy.sparse as sp
import torch
from time import time
import numpy as np
import scipy.sparse as sp
import torch
import torch.nn.functional as F
import scipy.sparse as sp
from torch import nn
import pandas as pd
import os
from datetime import datetime

#from utils.load_data import Data
#from utils.parser import parse_args
#from utils.helper_functions import early_stopping,\
                                   #train,\
                                   #split_matrix,\
                                   #compute_ndcg_k,\
                                   #eval_model

#from google.colab import drive
#drive.mount('/content/drive')
#data_dir = '/content/drive/My Drive/Colab Notebooks/NGCFPytorch/data/'
data_dir = './data/'
dataset = 'Gowella'
batch_size = 1024
layers = eval('[64,64]')
emb_dim = 64
lr = 0.0001
reg = 1e-5
mess_dropout = 0.1
node_dropout = 0.
k = 20
argssave_results = 1
argsn_epochs = 400
argseval_N = 1

# %% [markdown]
# #1

# %%
class Data(object):
    def __init__(self, path, batch_size):
        self.path = path
        self.batch_size = batch_size

        train_file = path + '/train.txt'
        test_file = path + '/test.txt'

        #get number of users and items
        self.n_users, self.n_items = 0, 0
        self.n_train, self.n_test = 0, 0
        self.neg_pools = {}

        self.exist_users = []

        # search train_file for max user_id/item_id
        with open(train_file) as f:
            for l in f.readlines():
                if len(l) > 0:
                    l = l.strip('\n').split(' ')
                    items = [int(i) for i in l[1:]]
                    # first element is the user_id, rest are items
                    uid = int(l[0])
                    self.exist_users.append(uid)
                    # item/user with highest number is number of items/users
                    self.n_items = max(self.n_items, max(items))
                    self.n_users = max(self.n_users, uid)
                    # number of interactions
                    self.n_train += len(items)

        # search test_file for max item_id
        with open(test_file) as f:
            for l in f.readlines():
                if len(l) > 0:
                    l = l.strip('\n')
                    try:
                        items = [int(i) for i in l.split(' ')[1:]]
                    except Exception:
                        continue
                    if not items:
                        print("empyt test exists")
                        pass
                    else:
                        self.n_items = max(self.n_items, max(items))
                        self.n_test += len(items)
        # adjust counters: user_id/item_id starts at 0
        self.n_items += 1
        self.n_users += 1

        self.print_statistics()

        # create interactions/ratings matrix 'R' # dok = dictionary of keys
        print('Creating interaction matrices R_train and R_test...')
        t1 = time()
        self.R_train = sp.dok_matrix((self.n_users, self.n_items), dtype=np.float32) 
        self.R_test = sp.dok_matrix((self.n_users, self.n_items), dtype=np.float32)

        self.train_items, self.test_set = {}, {}
        with open(train_file) as f_train:
            with open(test_file) as f_test:
                for l in f_train.readlines():
                    if len(l) == 0: break
                    l = l.strip('\n')
                    items = [int(i) for i in l.split(' ')]
                    uid, train_items = items[0], items[1:]
                    # enter 1 if user interacted with item
                    for i in train_items:
                        self.R_train[uid, i] = 1.
                    self.train_items[uid] = train_items

                for l in f_test.readlines():
                    if len(l) == 0: break
                    l = l.strip('\n')
                    try:
                        items = [int(i) for i in l.split(' ')]
                    except Exception:
                        continue
                    uid, test_items = items[0], items[1:]
                    for i in test_items:
                        self.R_test[uid, i] = 1.0
                    self.test_set[uid] = test_items
        print('Complete. Interaction matrices R_train and R_test created in', time() - t1, 'sec')

    # if exist, get adjacency matrix
    def get_adj_mat(self):
        try:
            t1 = time()
            adj_mat = sp.load_npz(self.path + '/s_adj_mat.npz')
            print('Loaded adjacency-matrix (shape:', adj_mat.shape,') in', time() - t1, 'sec.')

        except Exception:
            print('Creating adjacency-matrix...')
            adj_mat = self.create_adj_mat()
            sp.save_npz(self.path + '/s_adj_mat.npz', adj_mat)
        return adj_mat
    
    # create adjancency matrix
    def create_adj_mat(self):
        t1 = time()
        
        adj_mat = sp.dok_matrix((self.n_users + self.n_items, self.n_users + self.n_items), dtype=np.float32)
        adj_mat = adj_mat.tolil()
        R = self.R_train.tolil() # to list of lists

        adj_mat[:self.n_users, self.n_users:] = R
        adj_mat[self.n_users:, :self.n_users] = R.T
        adj_mat = adj_mat.todok()
        print('Complete. Adjacency-matrix created in', adj_mat.shape, time() - t1, 'sec.')

        t2 = time()

        # normalize adjacency matrix
        def normalized_adj_single(adj):
            rowsum = np.array(adj.sum(1))

            d_inv = np.power(rowsum, -.5).flatten()
            d_inv[np.isinf(d_inv)] = 0.
            d_mat_inv = sp.diags(d_inv)

            norm_adj = d_mat_inv.dot(adj).dot(d_mat_inv)
            return norm_adj.tocoo()

        print('Transforming adjacency-matrix to NGCF-adjacency matrix...')
        ngcf_adj_mat = normalized_adj_single(adj_mat) + sp.eye(adj_mat.shape[0])

        print('Complete. Transformed adjacency-matrix to NGCF-adjacency matrix in', time() - t2, 'sec.')
        return ngcf_adj_mat.tocsr()

    # create collections of N items that users never interacted with
    def negative_pool(self):
        t1 = time()
        for u in self.train_items.keys():
            neg_items = list(set(range(self.n_items)) - set(self.train_items[u]))
            pools = [rd.choice(neg_items) for _ in range(100)]
            self.neg_pools[u] = pools
        print('refresh negative pools', time() - t1)

    # sample data for mini-batches
    def sample(self):
        if self.batch_size <= self.n_users:
            users = rd.sample(self.exist_users, self.batch_size)
        else:
            users = [rd.choice(self.exist_users) for _ in range(self.batch_size)]

        def sample_pos_items_for_u(u, num):
            pos_items = self.train_items[u]
            n_pos_items = len(pos_items)
            pos_batch = []
            while True:
                if len(pos_batch) == num: break
                pos_id = np.random.randint(low=0, high=n_pos_items, size=1)[0]
                pos_i_id = pos_items[pos_id]

                if pos_i_id not in pos_batch:
                    pos_batch.append(pos_i_id)
            return pos_batch

        def sample_neg_items_for_u(u, num):
            neg_items = []
            while True:
                if len(neg_items) == num: break
                neg_id = np.random.randint(low=0, high=self.n_items,size=1)[0]
                if neg_id not in self.train_items[u] and neg_id not in neg_items:
                    neg_items.append(neg_id)
            return neg_items

        def sample_neg_items_for_u_from_pools(u, num):
            neg_items = list(set(self.neg_pools[u]) - set(self.train_items[u]))
            return rd.sample(neg_items, num)

        pos_items, neg_items = [], []
        for u in users:
            pos_items += sample_pos_items_for_u(u, 1)
            neg_items += sample_neg_items_for_u(u, 1)

        return users, pos_items, neg_items

    def get_num_users_items(self):
        return self.n_users, self.n_items

    def print_statistics(self):
        print('n_users=%d, n_items=%d' % (self.n_users, self.n_items))
        print('n_interactions=%d' % (self.n_train + self.n_test))
        print('n_train=%d, n_test=%d, sparsity=%.5f' % (self.n_train, self.n_test, (self.n_train + self.n_test)/(self.n_users * self.n_items)))

# %% [markdown]
# #2

# %%
def early_stopping(log_value, best_value, stopping_step, flag_step, expected_order='asc'):
    """
    Check if early_stopping is needed
    Function copied from original code
    """
    assert expected_order in ['asc', 'des']
    if (expected_order == 'asc' and log_value >= best_value) or (expected_order == 'des' and log_value <= best_value):
        stopping_step = 0
        best_value = log_value
    else:
        stopping_step += 1

    if stopping_step >= flag_step:
        print("Early stopping at step: {} log:{}".format(flag_step, log_value))
        should_stop = True
    else:
        should_stop = False

    return best_value, stopping_step, should_stop

def train(model, data_generator, optimizer):
    """
    Train the model PyTorch style

    Arguments:
    ---------
    model: PyTorch model
    data_generator: Data object
    optimizer: PyTorch optimizer
    """
    model.train()
    n_batch = data_generator.n_train // data_generator.batch_size + 1
    running_loss=0
    for _ in range(n_batch):
        u, i, j = data_generator.sample()
        optimizer.zero_grad()
        loss = model(u,i,j)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    return running_loss

def split_matrix(X, n_splits=100):
    """
    Split a matrix/Tensor into n_folds (for the user embeddings and the R matrices)

    Arguments:
    ---------
    X: matrix to be split
    n_folds: number of folds

    Returns:
    -------
    splits: split matrices
    """
    splits = []
    chunk_size = X.shape[0] // n_splits
    for i in range(n_splits):
        start = i * chunk_size
        end = X.shape[0] if i == n_splits - 1 else (i + 1) * chunk_size
        splits.append(X[start:end])
    return splits

def compute_ndcg_k(pred_items, test_items, test_indices, k):
    """
    Compute NDCG@k
    
    Arguments:
    ---------
    pred_items: binary tensor with 1s in those locations corresponding to the predicted item interactions
    test_items: binary tensor with 1s in locations corresponding to the real test interactions
    test_indices: tensor with the location of the top-k predicted items
    k: k'th-order 

    Returns:
    -------
    NDCG@k
    """
    r = (test_items * pred_items).gather(1, test_indices)
    f = torch.from_numpy(np.log2(np.arange(2, k+2))).float().cuda()
    dcg = (r[:, :k]/f).sum(1)
    dcg_max = (torch.sort(r, dim=1, descending=True)[0][:, :k]/f).sum(1)
    ndcg = dcg/dcg_max
    ndcg[torch.isnan(ndcg)] = 0
    return ndcg


def eval_model(u_emb, i_emb, Rtr, Rte, k):
    """
    Evaluate the model
    
    Arguments:
    ---------
    u_emb: User embeddings
    i_emb: Item embeddings
    Rtr: Sparse matrix with the training interactions
    Rte: Sparse matrix with the testing interactions
    k : kth-order for metrics
    
    Returns:
    --------
    result: Dictionary with lists correponding to the metrics at order k for k in Ks
    """
    # split matrices
    ue_splits = split_matrix(u_emb)
    tr_splits = split_matrix(Rtr)
    te_splits = split_matrix(Rte)

    recall_k, ndcg_k= [], []
    # compute results for split matrices
    for ue_f, tr_f, te_f in zip(ue_splits, tr_splits, te_splits):

        scores = torch.mm(ue_f, i_emb.t())

        test_items = torch.from_numpy(te_f.todense()).float().cuda()
        non_train_items = torch.from_numpy(1-(tr_f.todense())).float().cuda()
        scores = scores * non_train_items

        _, test_indices = torch.topk(scores, dim=1, k=k)
        pred_items = torch.zeros_like(scores).float()
        #pred_items.scatter_(dim=1,index=test_indices,src=torch.tensor(1.0).cuda())
        pred_items.scatter_(dim=1, index=test_indices,src=torch.ones_like(test_indices).float().cuda())

        topk_preds = torch.zeros_like(scores).float()
        #topk_preds.scatter_(dim=1,index=test_indices[:, :k],src=torch.tensor(1.0))
        topk_preds.scatter_(dim=1, index=test_indices[:, :k], src=torch.ones_like(test_indices[:, :k]).float().cuda())

        TP = (test_items * topk_preds).sum(1)
        rec = TP/test_items.sum(1)
        ndcg = compute_ndcg_k(pred_items, test_items, test_indices, k)

        recall_k.append(rec)
        ndcg_k.append(ndcg)

    return torch.cat(recall_k).mean(), torch.cat(ndcg_k).mean()

# %% [markdown]
# #3

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class NGCF(nn.Module):
    def __init__(self, n_users, n_items, emb_dim, layers, reg, node_dropout, mess_dropout,
        adj_mtx):
        super().__init__()

        # initialize Class attributes
        self.n_users = n_users
        self.n_items = n_items
        self.emb_dim = emb_dim
        self.adj_mtx = adj_mtx
        self.laplacian = adj_mtx - sp.eye(adj_mtx.shape[0])
        self.reg = reg
        self.layers = layers
        self.n_layers = len(self.layers)
        self.node_dropout = node_dropout
        self.mess_dropout = mess_dropout

        #self.u_g_embeddings = nn.Parameter(torch.empty(n_users, emb_dim+np.sum(self.layers)))
        #self.i_g_embeddings = nn.Parameter(torch.empty(n_items, emb_dim+np.sum(self.layers)))

        # Initialize weights
        self.weight_dict = self._init_weights()
        print("Weights initialized.")

        # Create Matrix 'A', PyTorch sparse tensor of SP adjacency_mtx
        self.A = self._convert_sp_mat_to_sp_tensor(self.adj_mtx)
        self.L = self._convert_sp_mat_to_sp_tensor(self.laplacian)

    # initialize weights
    def _init_weights(self):
        print("Initializing weights...")
        weight_dict = nn.ParameterDict()

        initializer = torch.nn.init.xavier_uniform_
        
        weight_dict['user_embedding'] = nn.Parameter(initializer(torch.empty(self.n_users, self.emb_dim).to(device)))
        weight_dict['item_embedding'] = nn.Parameter(initializer(torch.empty(self.n_items, self.emb_dim).to(device)))

        weight_size_list = [self.emb_dim] + self.layers

        for k in range(self.n_layers):
            weight_dict['W_gc_%d' %k] = nn.Parameter(initializer(torch.empty(weight_size_list[k], weight_size_list[k+1]).to(device)))
            weight_dict['b_gc_%d' %k] = nn.Parameter(initializer(torch.empty(1, weight_size_list[k+1]).to(device)))
            
            weight_dict['W_bi_%d' %k] = nn.Parameter(initializer(torch.empty(weight_size_list[k], weight_size_list[k+1]).to(device)))
            weight_dict['b_bi_%d' %k] = nn.Parameter(initializer(torch.empty(1, weight_size_list[k+1]).to(device)))
           
        return weight_dict

    # convert sparse matrix into sparse PyTorch tensor
    def _convert_sp_mat_to_sp_tensor(self, X):
        """
        Convert scipy sparse matrix to PyTorch sparse matrix

        Arguments:
        ----------
        X = Adjacency matrix, scipy sparse matrix
        """
        coo = X.tocoo().astype(np.float32)
        i = torch.LongTensor(np.mat([coo.row, coo.col]))
        v = torch.FloatTensor(coo.data)
        res = torch.sparse.FloatTensor(i, v, coo.shape).to(device)
        return res

    # apply node_dropout
    def _droupout_sparse(self, X):
        """
        Drop individual locations in X
        
        Arguments:
        ---------
        X = adjacency matrix (PyTorch sparse tensor)
        dropout = fraction of nodes to drop
        noise_shape = number of non non-zero entries of X
        """
        
        node_dropout_mask = ((self.node_dropout) + torch.rand(X._nnz())).floor().bool().to(device)
        i = X.coalesce().indices()
        v = X.coalesce()._values()
        i[:,node_dropout_mask] = 0
        v[node_dropout_mask] = 0
        X_dropout = torch.sparse.FloatTensor(i, v, X.shape).to(X.device)

        return  X_dropout.mul(1/(1-self.node_dropout))

    def forward(self, u, i, j):
        """
        Computes the forward pass
        
        Arguments:
        ---------
        u = user
        i = positive item (user interacted with item)
        j = negative item (user did not interact with item)
        """
        # apply drop-out mask
        A_hat = self._droupout_sparse(self.A) if self.node_dropout > 0 else self.A
        L_hat = self._droupout_sparse(self.L) if self.node_dropout > 0 else self.L

        ego_embeddings = torch.cat([self.weight_dict['user_embedding'], self.weight_dict['item_embedding']], 0)

        all_embeddings = [ego_embeddings]

        # forward pass for 'n' propagation layers
        for k in range(self.n_layers):

            # weighted sum messages of neighbours
            side_embeddings = torch.sparse.mm(A_hat, ego_embeddings)
            side_L_embeddings = torch.sparse.mm(L_hat, ego_embeddings)

            # transformed sum weighted sum messages of neighbours
            sum_embeddings = torch.matmul(side_embeddings, self.weight_dict['W_gc_%d' % k]) + self.weight_dict['b_gc_%d' % k]

            # bi messages of neighbours
            bi_embeddings = torch.mul(ego_embeddings, side_L_embeddings)
            # transformed bi messages of neighbours
            bi_embeddings = torch.matmul(bi_embeddings, self.weight_dict['W_bi_%d' % k]) + self.weight_dict['b_bi_%d' % k]

            # non-linear activation 
            ego_embeddings = F.leaky_relu(sum_embeddings + bi_embeddings)
            # + message dropout
            mess_dropout_mask = nn.Dropout(self.mess_dropout)
            ego_embeddings = mess_dropout_mask(ego_embeddings)

            # normalize activation
            norm_embeddings = F.normalize(ego_embeddings, p=2, dim=1)

            all_embeddings.append(norm_embeddings)

        all_embeddings = torch.cat(all_embeddings, 1)
        
        # back to user/item dimension
        u_g_embeddings, i_g_embeddings = all_embeddings.split([self.n_users, self.n_items], 0)

        self.u_g_embeddings = nn.Parameter(u_g_embeddings)
        self.i_g_embeddings = nn.Parameter(i_g_embeddings)
        
        u_emb = u_g_embeddings[u] # user embeddings
        p_emb = i_g_embeddings[i] # positive item embeddings
        n_emb = i_g_embeddings[j] # negative item embeddings

        y_ui = torch.mul(u_emb, p_emb).sum(dim=1)
        y_uj = torch.mul(u_emb, n_emb).sum(dim=1)
        log_prob = (torch.log(torch.sigmoid(y_ui-y_uj))).mean()

        # compute bpr-loss
        bpr_loss = -log_prob
        if self.reg > 0.:
            l2norm = (torch.sum(u_emb**2)/2. + torch.sum(p_emb**2)/2. + torch.sum(n_emb**2)/2.) / u_emb.shape[0]
            l2reg  = self.reg*l2norm
            bpr_loss =  -log_prob + l2reg

        return bpr_loss

# %% [markdown]
# #4

# %%
#from ngcf import NGCF

use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.cuda.set_device(0)



# generate the NGCF-adjacency matrix
data_generator = Data(path=data_dir + dataset, batch_size=batch_size)
adj_mtx = data_generator.get_adj_mat()

# create model name and save
modelname =  "NGCF" + \
    "_bs_" + str(batch_size) + \
    "_nemb_" + str(emb_dim) + \
    "_layers_" + str(layers) + \
    "_nodedr_" + str(node_dropout) + \
    "_messdr_" + str(mess_dropout) + \
    "_reg_" + str(reg) + \
    "_lr_"  + str(lr)

# create NGCF model
model = NGCF(data_generator.n_users, 
              data_generator.n_items,
              emb_dim,
              layers,
              reg,
              node_dropout,
              mess_dropout,
              adj_mtx)
if use_cuda:
    model = model.cuda()

# current best metric
cur_best_metric = 0

# Adam optimizer
optimizer = torch.optim.Adam(model.parameters(), lr)

# Set values for early stopping
cur_best_loss, stopping_step, should_stop = 1e3, 0, False
today = datetime.now()

print("Start at " + str(today))
print("Using " + str(device) + " for computations")
print("Params on CUDA: " + str(next(model.parameters()).is_cuda))

results = {"Epoch": [],
            "Loss": [],
            "Recall": [],
            "NDCG": [],
            "Training Time": []}

for epoch in range(argsn_epochs):

    t1 = time()
    loss = train(model, data_generator, optimizer)
    training_time = time()-t1
    print("Epoch: {}, Training time: {:.2f}s, Loss: {:.4f}".
        format(epoch, training_time, loss))

    # print test evaluation metrics every N epochs (provided by args.eval_N)
    if epoch % argseval_N  == (argseval_N - 1):
        with torch.no_grad():
            t2 = time()
            recall, ndcg = eval_model(model.u_g_embeddings.detach(),
                                      model.i_g_embeddings.detach(),
                                      data_generator.R_train,
                                      data_generator.R_test,
                                      k)
        print(
            "Evaluate current model:\n",
            "Epoch: {}, Validation time: {:.2f}s".format(epoch, time()-t2),"\n",
            "Loss: {:.4f}:".format(loss), "\n",
            "Recall@{}: {:.4f}".format(k, recall), "\n",
            "NDCG@{}: {:.4f}".format(k, ndcg)
            )

        cur_best_metric, stopping_step, should_stop = \
        early_stopping(recall, cur_best_metric, stopping_step, flag_step=50)

        # save results in dict
        results['Epoch'].append(epoch)
        results['Loss'].append(loss)
        results['Recall'].append(recall.item())
        results['NDCG'].append(ndcg.item())
        results['Training Time'].append(training_time)
    else:
        # save results in dict
        results['Epoch'].append(epoch)
        results['Loss'].append(loss)
        results['Recall'].append(None)
        results['NDCG'].append(None)
        results['Training Time'].append(training_time)

    if should_stop == True: break

# save
if argssave_results:
    date = today.strftime("%d%m%Y_%H%M")

    # save model as .pt file
    if os.path.isdir("./models"):
        torch.save(model.state_dict(), "./models/" + str(date) + "_" + modelname + "_" + dataset + ".pt")
    else:
        os.mkdir("./models")
        torch.save(model.state_dict(), "./models/" + str(date) + "_" + modelname + "_" + dataset + ".pt")

    # save results as pandas dataframe
    results_df = pd.DataFrame(results)
    results_df.set_index('Epoch', inplace=True)
    if os.path.isdir("./results"):
        results_df.to_csv("./results/" + str(date) + "_" + modelname + "_" + dataset + ".csv")
    else:
        os.mkdir("./results")
        results_df.to_csv("./results/" + str(date) + "_" + modelname + "_" + dataset + ".csv")
    # plot loss
    results_df['Loss'].plot(figsize=(12,8), title='Loss')
# Out:
# n_users=29858, n_items=40981
# n_interactions=1027370
# n_train=810128, n_test=217242, sparsity=0.00084
# Creating interaction matrices R_train and R_test...
# Complete. Interaction matrices R_train and R_test created in 11.536890745162964 sec
# Loaded adjacency-matrix (shape: (70839, 70839) ) in 0.1290290355682373 sec.
# Initializing weights...
# Weights initialized.
# Start at 2022-05-30 13:54:22.240277
# Using cuda for computations
# Params on CUDA: True
# Epoch: 0, Training time: 167.41s, Loss: 540.3261
# Evaluate current model:
#  Epoch: 0, Validation time: 39.86s
#  Loss: 540.3261:
#  Recall@20: 0.0018
#  NDCG@20: 0.0065
# Epoch: 1, Training time: 161.58s, Loss: 365.1572
# Evaluate current model:
#  Epoch: 1, Validation time: 38.43s
#  Loss: 365.1572:
#  Recall@20: 0.0023
#  NDCG@20: 0.0079
# Epoch: 2, Training time: 163.52s, Loss: 306.1570
# Evaluate current model:
#  Epoch: 2, Validation time: 38.91s
#  Loss: 306.1570:
#  Recall@20: 0.0028
#  NDCG@20: 0.0083
# Epoch: 3, Training time: 162.51s, Loss: 291.9115
# Evaluate current model:
#  Epoch: 3, Validation time: 39.72s
#  Loss: 291.9115:
#  Recall@20: 0.0043
#  NDCG@20: 0.0127
# Epoch: 4, Training time: 164.50s, Loss: 279.5028
# Evaluate current model:
#  Epoch: 4, Validation time: 40.86s
#  Loss: 279.5028:
#  Recall@20: 0.0091
#  NDCG@20: 0.0258
# Epoch: 5, Training time: 161.93s, Loss: 267.6144
# Evaluate current model:
#  Epoch: 5, Validation time: 38.98s
#  Loss: 267.6144:
#  Recall@20: 0.0159
#  NDCG@20: 0.0432
# Epoch: 6, Training time: 162.12s, Loss: 253.9137
# Evaluate current model:
#  Epoch: 6, Validation time: 34.33s
#  Loss: 253.9137:
#  Recall@20: 0.0200
#  NDCG@20: 0.0482
# Epoch: 7, Training time: 161.93s, Loss: 240.6889
# Evaluate current model:
#  Epoch: 7, Validation time: 34.52s
#  Loss: 240.6889:
#  Recall@20: 0.0265
#  NDCG@20: 0.0624
# Epoch: 8, Training time: 161.12s, Loss: 229.6985
# Evaluate current model:
#  Epoch: 8, Validation time: 33.82s
#  Loss: 229.6985:
#  Recall@20: 0.0283
#  NDCG@20: 0.0688
# Epoch: 9, Training time: 161.94s, Loss: 220.7495
# Evaluate current model:
#  Epoch: 9, Validation time: 33.63s
#  Loss: 220.7495:
#  Recall@20: 0.0321
#  NDCG@20: 0.0738
# Epoch: 10, Training time: 164.03s, Loss: 212.3982
# Evaluate current model:
#  Epoch: 10, Validation time: 34.47s
#  Loss: 212.3982:
#  Recall@20: 0.0343
#  NDCG@20: 0.0792
# Epoch: 11, Training time: 164.30s, Loss: 204.7718
# Evaluate current model:
#  Epoch: 11, Validation time: 33.68s
#  Loss: 204.7718:
#  Recall@20: 0.0394
#  NDCG@20: 0.0896
# Epoch: 12, Training time: 160.62s, Loss: 198.3488
# Evaluate current model:
#  Epoch: 12, Validation time: 33.58s
#  Loss: 198.3488:
#  Recall@20: 0.0403
#  NDCG@20: 0.0917
# Epoch: 13, Training time: 160.66s, Loss: 192.9143
# Evaluate current model:
#  Epoch: 13, Validation time: 36.30s
#  Loss: 192.9143:
#  Recall@20: 0.0429
#  NDCG@20: 0.0974
# Epoch: 14, Training time: 163.54s, Loss: 187.6334
# Evaluate current model:
#  Epoch: 14, Validation time: 35.53s
#  Loss: 187.6334:
#  Recall@20: 0.0439
#  NDCG@20: 0.0974
# Epoch: 15, Training time: 162.09s, Loss: 184.4883
# Evaluate current model:
#  Epoch: 15, Validation time: 35.66s
#  Loss: 184.4883:
#  Recall@20: 0.0454
#  NDCG@20: 0.1028
# Epoch: 16, Training time: 162.73s, Loss: 181.1277
# Evaluate current model:
#  Epoch: 16, Validation time: 35.47s
#  Loss: 181.1277:
#  Recall@20: 0.0473
#  NDCG@20: 0.1063
# Epoch: 17, Training time: 161.49s, Loss: 178.2856
# Evaluate current model:
#  Epoch: 17, Validation time: 35.51s
#  Loss: 178.2856:
#  Recall@20: 0.0482
#  NDCG@20: 0.1094
# Epoch: 18, Training time: 161.62s, Loss: 175.8073
# Evaluate current model:
#  Epoch: 18, Validation time: 35.52s
#  Loss: 175.8073:
#  Recall@20: 0.0485
#  NDCG@20: 0.1082
# Epoch: 19, Training time: 161.62s, Loss: 173.6943
# Evaluate current model:
#  Epoch: 19, Validation time: 35.49s
#  Loss: 173.6943:
#  Recall@20: 0.0507
#  NDCG@20: 0.1134
# Epoch: 20, Training time: 161.64s, Loss: 170.9263
# Evaluate current model:
#  Epoch: 20, Validation time: 35.63s
#  Loss: 170.9263:
#  Recall@20: 0.0524
#  NDCG@20: 0.1150
# Epoch: 21, Training time: 161.56s, Loss: 168.7623
# Evaluate current model:
#  Epoch: 21, Validation time: 35.47s
#  Loss: 168.7623:
#  Recall@20: 0.0544
#  NDCG@20: 0.1195
# Epoch: 22, Training time: 161.60s, Loss: 165.8942
# Evaluate current model:
#  Epoch: 22, Validation time: 35.62s
#  Loss: 165.8942:
#  Recall@20: 0.0567
#  NDCG@20: 0.1246
# Epoch: 23, Training time: 161.55s, Loss: 164.0264
# Evaluate current model:
#  Epoch: 23, Validation time: 35.25s
#  Loss: 164.0264:
#  Recall@20: 0.0582
#  NDCG@20: 0.1267
# Epoch: 24, Training time: 161.76s, Loss: 162.0510
# Evaluate current model:
#  Epoch: 24, Validation time: 35.53s
#  Loss: 162.0510:
#  Recall@20: 0.0575
#  NDCG@20: 0.1264
# Epoch: 25, Training time: 161.47s, Loss: 160.3331
# Evaluate current model:
#  Epoch: 25, Validation time: 35.75s
#  Loss: 160.3331:
#  Recall@20: 0.0598
#  NDCG@20: 0.1323
# Epoch: 26, Training time: 161.57s, Loss: 158.6805
# Evaluate current model:
#  Epoch: 26, Validation time: 35.67s
#  Loss: 158.6805:
#  Recall@20: 0.0609
#  NDCG@20: 0.1348
# Epoch: 27, Training time: 161.63s, Loss: 157.0711
# Evaluate current model:
#  Epoch: 27, Validation time: 35.16s
#  Loss: 157.0711:
#  Recall@20: 0.0619
#  NDCG@20: 0.1361
# Epoch: 28, Training time: 161.63s, Loss: 155.2255
# Evaluate current model:
#  Epoch: 28, Validation time: 35.39s
#  Loss: 155.2255:
#  Recall@20: 0.0633
#  NDCG@20: 0.1388
# Epoch: 29, Training time: 161.60s, Loss: 153.8439
# Evaluate current model:
#  Epoch: 29, Validation time: 35.03s
#  Loss: 153.8439:
#  Recall@20: 0.0640
#  NDCG@20: 0.1416
# Epoch: 30, Training time: 161.53s, Loss: 152.2172
# Evaluate current model:
#  Epoch: 30, Validation time: 35.16s
#  Loss: 152.2172:
#  Recall@20: 0.0654
#  NDCG@20: 0.1439
# Epoch: 31, Training time: 161.68s, Loss: 150.7334
# Evaluate current model:
#  Epoch: 31, Validation time: 35.17s
#  Loss: 150.7334:
#  Recall@20: 0.0668
#  NDCG@20: 0.1449
# Epoch: 32, Training time: 161.86s, Loss: 149.2711
# Evaluate current model:
#  Epoch: 32, Validation time: 35.04s
#  Loss: 149.2711:
#  Recall@20: 0.0665
#  NDCG@20: 0.1462
# Epoch: 33, Training time: 161.50s, Loss: 147.3195
# Evaluate current model:
#  Epoch: 33, Validation time: 35.75s
#  Loss: 147.3195:
#  Recall@20: 0.0682
#  NDCG@20: 0.1507
# Epoch: 34, Training time: 161.98s, Loss: 146.1812
# Evaluate current model:
#  Epoch: 34, Validation time: 35.25s
#  Loss: 146.1812:
#  Recall@20: 0.0703
#  NDCG@20: 0.1540
# Epoch: 35, Training time: 163.71s, Loss: 144.8755
# Evaluate current model:
#  Epoch: 35, Validation time: 35.51s
#  Loss: 144.8755:
#  Recall@20: 0.0729
#  NDCG@20: 0.1610
# Epoch: 36, Training time: 163.71s, Loss: 143.1206
# Evaluate current model:
#  Epoch: 36, Validation time: 35.84s
#  Loss: 143.1206:
#  Recall@20: 0.0738
#  NDCG@20: 0.1592
# Epoch: 37, Training time: 162.11s, Loss: 141.3189
# Evaluate current model:
#  Epoch: 37, Validation time: 35.56s
#  Loss: 141.3189:
#  Recall@20: 0.0752
#  NDCG@20: 0.1638
# Epoch: 38, Training time: 163.44s, Loss: 140.5659
# Evaluate current model:
#  Epoch: 38, Validation time: 34.92s
#  Loss: 140.5659:
#  Recall@20: 0.0753
#  NDCG@20: 0.1643
# Epoch: 39, Training time: 163.95s, Loss: 138.6600
# Evaluate current model:
#  Epoch: 39, Validation time: 35.04s
#  Loss: 138.6600:
#  Recall@20: 0.0785
#  NDCG@20: 0.1732
# Epoch: 40, Training time: 162.42s, Loss: 137.3390
# Evaluate current model:
#  Epoch: 40, Validation time: 35.39s
#  Loss: 137.3390:
#  Recall@20: 0.0807
#  NDCG@20: 0.1767
# Epoch: 41, Training time: 161.36s, Loss: 135.6827
# Evaluate current model:
#  Epoch: 41, Validation time: 35.25s
#  Loss: 135.6827:
#  Recall@20: 0.0819
#  NDCG@20: 0.1795
# Epoch: 42, Training time: 161.50s, Loss: 134.0375
# Evaluate current model:
#  Epoch: 42, Validation time: 34.96s
#  Loss: 134.0375:
#  Recall@20: 0.0835
#  NDCG@20: 0.1844
# Epoch: 43, Training time: 161.06s, Loss: 133.0671
# Evaluate current model:
#  Epoch: 43, Validation time: 34.50s
#  Loss: 133.0671:
#  Recall@20: 0.0848
#  NDCG@20: 0.1845
# Epoch: 44, Training time: 161.37s, Loss: 131.6626
# Evaluate current model:
#  Epoch: 44, Validation time: 35.05s
#  Loss: 131.6626:
#  Recall@20: 0.0873
#  NDCG@20: 0.1929
# Epoch: 45, Training time: 161.49s, Loss: 129.7382
# Evaluate current model:
#  Epoch: 45, Validation time: 35.36s
#  Loss: 129.7382:
#  Recall@20: 0.0891
#  NDCG@20: 0.1973
# Epoch: 46, Training time: 161.60s, Loss: 128.4957
# Evaluate current model:
#  Epoch: 46, Validation time: 35.27s
#  Loss: 128.4957:
#  Recall@20: 0.0893
#  NDCG@20: 0.1980
# Epoch: 47, Training time: 161.48s, Loss: 126.8620
# Evaluate current model:
#  Epoch: 47, Validation time: 35.26s
#  Loss: 126.8620:
#  Recall@20: 0.0904
#  NDCG@20: 0.1992
# Epoch: 48, Training time: 161.24s, Loss: 125.4346
# Evaluate current model:
#  Epoch: 48, Validation time: 35.12s
#  Loss: 125.4346:
#  Recall@20: 0.0927
#  NDCG@20: 0.2029
# Epoch: 49, Training time: 161.27s, Loss: 123.9463
# Evaluate current model:
#  Epoch: 49, Validation time: 34.97s
#  Loss: 123.9463:
#  Recall@20: 0.0935
#  NDCG@20: 0.2063
# Epoch: 50, Training time: 161.38s, Loss: 122.0276
# Evaluate current model:
#  Epoch: 50, Validation time: 34.99s
#  Loss: 122.0276:
#  Recall@20: 0.0939
#  NDCG@20: 0.2076
# Epoch: 51, Training time: 161.34s, Loss: 120.5663
# Evaluate current model:
#  Epoch: 51, Validation time: 35.00s
#  Loss: 120.5663:
#  Recall@20: 0.0958
#  NDCG@20: 0.2095
# Epoch: 52, Training time: 161.52s, Loss: 119.1438
# Evaluate current model:
#  Epoch: 52, Validation time: 34.99s
#  Loss: 119.1438:
#  Recall@20: 0.0969
#  NDCG@20: 0.2140
# Epoch: 53, Training time: 161.44s, Loss: 117.5878
# Evaluate current model:
#  Epoch: 53, Validation time: 35.25s
#  Loss: 117.5878:
#  Recall@20: 0.0980
#  NDCG@20: 0.2160
# Epoch: 54, Training time: 161.44s, Loss: 115.7900
# Evaluate current model:
#  Epoch: 54, Validation time: 35.38s
#  Loss: 115.7900:
#  Recall@20: 0.0985
#  NDCG@20: 0.2190
# Epoch: 55, Training time: 161.49s, Loss: 114.1771
# Evaluate current model:
#  Epoch: 55, Validation time: 35.00s
#  Loss: 114.1771:
#  Recall@20: 0.0997
#  NDCG@20: 0.2202
# Epoch: 56, Training time: 161.48s, Loss: 112.4747
# Evaluate current model:
#  Epoch: 56, Validation time: 35.11s
#  Loss: 112.4747:
#  Recall@20: 0.1015
#  NDCG@20: 0.2244
# Epoch: 57, Training time: 161.17s, Loss: 111.0184
# Evaluate current model:
#  Epoch: 57, Validation time: 34.96s
#  Loss: 111.0184:
#  Recall@20: 0.1029
#  NDCG@20: 0.2271
# Epoch: 58, Training time: 161.32s, Loss: 109.1735
# Evaluate current model:
#  Epoch: 58, Validation time: 34.77s
#  Loss: 109.1735:
#  Recall@20: 0.1028
#  NDCG@20: 0.2271
# Epoch: 59, Training time: 161.26s, Loss: 108.0501
# Evaluate current model:
#  Epoch: 59, Validation time: 34.67s
#  Loss: 108.0501:
#  Recall@20: 0.1033
#  NDCG@20: 0.2280
# Epoch: 60, Training time: 160.37s, Loss: 106.2590
# Evaluate current model:
#  Epoch: 60, Validation time: 33.42s
#  Loss: 106.2590:
#  Recall@20: 0.1049
#  NDCG@20: 0.2302
# Epoch: 61, Training time: 160.10s, Loss: 104.5581
# Evaluate current model:
#  Epoch: 61, Validation time: 33.40s
#  Loss: 104.5581:
#  Recall@20: 0.1047
#  NDCG@20: 0.2306
# Epoch: 62, Training time: 160.13s, Loss: 103.0398
# Evaluate current model:
#  Epoch: 62, Validation time: 33.57s
#  Loss: 103.0398:
#  Recall@20: 0.1046
#  NDCG@20: 0.2314
# Epoch: 63, Training time: 160.08s, Loss: 101.6675
# Evaluate current model:
#  Epoch: 63, Validation time: 33.38s
#  Loss: 101.6675:
#  Recall@20: 0.1059
#  NDCG@20: 0.2343
# Epoch: 64, Training time: 160.06s, Loss: 100.0936
# Evaluate current model:
#  Epoch: 64, Validation time: 33.33s
#  Loss: 100.0936:
#  Recall@20: 0.1069
#  NDCG@20: 0.2347
# Epoch: 65, Training time: 160.04s, Loss: 98.3849
# Evaluate current model:
#  Epoch: 65, Validation time: 33.39s
#  Loss: 98.3849:
#  Recall@20: 0.1074
#  NDCG@20: 0.2355
# Epoch: 66, Training time: 160.09s, Loss: 96.9459
# Evaluate current model:
#  Epoch: 66, Validation time: 33.47s
#  Loss: 96.9459:
#  Recall@20: 0.1083
#  NDCG@20: 0.2374
# Epoch: 67, Training time: 159.95s, Loss: 95.2609
# Evaluate current model:
#  Epoch: 67, Validation time: 33.36s
#  Loss: 95.2609:
#  Recall@20: 0.1083
#  NDCG@20: 0.2378
# Epoch: 68, Training time: 160.11s, Loss: 93.9316
# Evaluate current model:
#  Epoch: 68, Validation time: 33.50s
#  Loss: 93.9316:
#  Recall@20: 0.1087
#  NDCG@20: 0.2382
# Epoch: 69, Training time: 160.04s, Loss: 92.5417
# Evaluate current model:
#  Epoch: 69, Validation time: 33.39s
#  Loss: 92.5417:
#  Recall@20: 0.1098
#  NDCG@20: 0.2407
# Epoch: 70, Training time: 159.99s, Loss: 91.0884
# Evaluate current model:
#  Epoch: 70, Validation time: 33.45s
#  Loss: 91.0884:
#  Recall@20: 0.1104
#  NDCG@20: 0.2421
# Epoch: 71, Training time: 161.46s, Loss: 89.4170
# Evaluate current model:
#  Epoch: 71, Validation time: 33.91s
#  Loss: 89.4170:
#  Recall@20: 0.1106
#  NDCG@20: 0.2416
# Epoch: 72, Training time: 164.12s, Loss: 87.9520
# Evaluate current model:
#  Epoch: 72, Validation time: 34.78s
#  Loss: 87.9520:
#  Recall@20: 0.1115
#  NDCG@20: 0.2439
# Epoch: 73, Training time: 164.80s, Loss: 86.8772
# Evaluate current model:
#  Epoch: 73, Validation time: 39.26s
#  Loss: 86.8772:
#  Recall@20: 0.1112
#  NDCG@20: 0.2428
# Epoch: 74, Training time: 164.58s, Loss: 85.5434
# Evaluate current model:
#  Epoch: 74, Validation time: 34.74s
#  Loss: 85.5434:
#  Recall@20: 0.1111
#  NDCG@20: 0.2435
# Epoch: 75, Training time: 165.76s, Loss: 83.9197
# Evaluate current model:
#  Epoch: 75, Validation time: 35.02s
#  Loss: 83.9197:
#  Recall@20: 0.1125
#  NDCG@20: 0.2460
# Epoch: 76, Training time: 163.79s, Loss: 82.7991
# Evaluate current model:
#  Epoch: 76, Validation time: 34.25s
#  Loss: 82.7991:
#  Recall@20: 0.1121
#  NDCG@20: 0.2452
# Epoch: 77, Training time: 163.09s, Loss: 81.5004
# Evaluate current model:
#  Epoch: 77, Validation time: 33.24s
#  Loss: 81.5004:
#  Recall@20: 0.1135
#  NDCG@20: 0.2478
# Epoch: 78, Training time: 160.33s, Loss: 80.4495
# Evaluate current model:
#  Epoch: 78, Validation time: 33.58s
#  Loss: 80.4495:
#  Recall@20: 0.1137
#  NDCG@20: 0.2467
# Epoch: 79, Training time: 163.13s, Loss: 79.1442
# Evaluate current model:
#  Epoch: 79, Validation time: 35.19s
#  Loss: 79.1442:
#  Recall@20: 0.1138
#  NDCG@20: 0.2480
# Epoch: 80, Training time: 161.02s, Loss: 77.6954
# Evaluate current model:
#  Epoch: 80, Validation time: 33.40s
#  Loss: 77.6954:
#  Recall@20: 0.1134
#  NDCG@20: 0.2473
# Epoch: 81, Training time: 160.08s, Loss: 76.5143
# Evaluate current model:
#  Epoch: 81, Validation time: 33.28s
#  Loss: 76.5143:
#  Recall@20: 0.1138
#  NDCG@20: 0.2482
# Epoch: 82, Training time: 160.19s, Loss: 75.6192
# Evaluate current model:
#  Epoch: 82, Validation time: 33.42s
#  Loss: 75.6192:
#  Recall@20: 0.1144
#  NDCG@20: 0.2491
# Epoch: 83, Training time: 160.38s, Loss: 74.3480
# Evaluate current model:
#  Epoch: 83, Validation time: 33.30s
#  Loss: 74.3480:
#  Recall@20: 0.1149
#  NDCG@20: 0.2503
# Epoch: 84, Training time: 161.76s, Loss: 73.5074
# Evaluate current model:
#  Epoch: 84, Validation time: 35.18s
#  Loss: 73.5074:
#  Recall@20: 0.1156
#  NDCG@20: 0.2499
# Epoch: 85, Training time: 162.40s, Loss: 72.0799
# Evaluate current model:
#  Epoch: 85, Validation time: 33.42s
#  Loss: 72.0799:
#  Recall@20: 0.1148
#  NDCG@20: 0.2509
# Epoch: 86, Training time: 160.18s, Loss: 70.9355
# Evaluate current model:
#  Epoch: 86, Validation time: 33.47s
#  Loss: 70.9355:
#  Recall@20: 0.1153
#  NDCG@20: 0.2514
# Epoch: 87, Training time: 160.04s, Loss: 69.9039
# Evaluate current model:
#  Epoch: 87, Validation time: 33.40s
#  Loss: 69.9039:
#  Recall@20: 0.1154
#  NDCG@20: 0.2520
# Epoch: 88, Training time: 160.27s, Loss: 68.8148
# Evaluate current model:
#  Epoch: 88, Validation time: 33.22s
#  Loss: 68.8148:
#  Recall@20: 0.1165
#  NDCG@20: 0.2530
# Epoch: 89, Training time: 160.14s, Loss: 67.9298
# Evaluate current model:
#  Epoch: 89, Validation time: 33.82s
#  Loss: 67.9298:
#  Recall@20: 0.1165
#  NDCG@20: 0.2542
# Epoch: 90, Training time: 160.14s, Loss: 66.8696
# Evaluate current model:
#  Epoch: 90, Validation time: 33.46s
#  Loss: 66.8696:
#  Recall@20: 0.1165
#  NDCG@20: 0.2533
# Epoch: 91, Training time: 160.11s, Loss: 66.0488
# Evaluate current model:
#  Epoch: 91, Validation time: 33.51s
#  Loss: 66.0488:
#  Recall@20: 0.1174
#  NDCG@20: 0.2542
# Epoch: 92, Training time: 160.18s, Loss: 65.1954
# Evaluate current model:
#  Epoch: 92, Validation time: 33.49s
#  Loss: 65.1954:
#  Recall@20: 0.1173
#  NDCG@20: 0.2549
# Epoch: 93, Training time: 160.16s, Loss: 64.2682
# Evaluate current model:
#  Epoch: 93, Validation time: 33.35s
#  Loss: 64.2682:
#  Recall@20: 0.1176
#  NDCG@20: 0.2544
# Epoch: 94, Training time: 160.09s, Loss: 63.3447
# Evaluate current model:
#  Epoch: 94, Validation time: 33.48s
#  Loss: 63.3447:
#  Recall@20: 0.1171
#  NDCG@20: 0.2548
# Epoch: 95, Training time: 160.16s, Loss: 62.4699
# Evaluate current model:
#  Epoch: 95, Validation time: 33.25s
#  Loss: 62.4699:
#  Recall@20: 0.1178
#  NDCG@20: 0.2561
# Epoch: 96, Training time: 160.17s, Loss: 61.4107
# Evaluate current model:
#  Epoch: 96, Validation time: 33.50s
#  Loss: 61.4107:
#  Recall@20: 0.1177
#  NDCG@20: 0.2556
# Epoch: 97, Training time: 160.09s, Loss: 60.6633
# Evaluate current model:
#  Epoch: 97, Validation time: 33.51s
#  Loss: 60.6633:
#  Recall@20: 0.1179
#  NDCG@20: 0.2565
# Epoch: 98, Training time: 160.14s, Loss: 60.0353
# Evaluate current model:
#  Epoch: 98, Validation time: 33.31s
#  Loss: 60.0353:
#  Recall@20: 0.1182
#  NDCG@20: 0.2570
# Epoch: 99, Training time: 160.20s, Loss: 58.9985
# Evaluate current model:
#  Epoch: 99, Validation time: 33.54s
#  Loss: 58.9985:
#  Recall@20: 0.1183
#  NDCG@20: 0.2563
# Epoch: 100, Training time: 160.55s, Loss: 58.3817
# Evaluate current model:
#  Epoch: 100, Validation time: 33.90s
#  Loss: 58.3817:
#  Recall@20: 0.1182
#  NDCG@20: 0.2575
# Epoch: 101, Training time: 160.39s, Loss: 57.3510
# Evaluate current model:
#  Epoch: 101, Validation time: 34.09s
#  Loss: 57.3510:
#  Recall@20: 0.1183
#  NDCG@20: 0.2569
# Epoch: 102, Training time: 164.00s, Loss: 56.6358
# Evaluate current model:
#  Epoch: 102, Validation time: 33.98s
#  Loss: 56.6358:
#  Recall@20: 0.1195
#  NDCG@20: 0.2581
# Epoch: 103, Training time: 162.12s, Loss: 56.4270
# Evaluate current model:
#  Epoch: 103, Validation time: 34.66s
#  Loss: 56.4270:
#  Recall@20: 0.1186
#  NDCG@20: 0.2566
# Epoch: 104, Training time: 162.71s, Loss: 55.5495
# Evaluate current model:
#  Epoch: 104, Validation time: 34.00s
#  Loss: 55.5495:
#  Recall@20: 0.1197
#  NDCG@20: 0.2584
# Epoch: 105, Training time: 162.27s, Loss: 54.5630
# Evaluate current model:
#  Epoch: 105, Validation time: 34.15s
#  Loss: 54.5630:
#  Recall@20: 0.1197
#  NDCG@20: 0.2584
# Epoch: 106, Training time: 161.57s, Loss: 54.2543
# Evaluate current model:
#  Epoch: 106, Validation time: 33.84s
#  Loss: 54.2543:
#  Recall@20: 0.1200
#  NDCG@20: 0.2592
# Epoch: 107, Training time: 162.33s, Loss: 53.5699
# Evaluate current model:
#  Epoch: 107, Validation time: 34.87s
#  Loss: 53.5699:
#  Recall@20: 0.1197
#  NDCG@20: 0.2591
# Epoch: 108, Training time: 161.87s, Loss: 52.7810
# Evaluate current model:
#  Epoch: 108, Validation time: 34.04s
#  Loss: 52.7810:
#  Recall@20: 0.1203
#  NDCG@20: 0.2590
# Epoch: 109, Training time: 161.84s, Loss: 52.4497
# Evaluate current model:
#  Epoch: 109, Validation time: 34.32s
#  Loss: 52.4497:
#  Recall@20: 0.1201
#  NDCG@20: 0.2591
# Epoch: 110, Training time: 162.88s, Loss: 51.5200
# Evaluate current model:
#  Epoch: 110, Validation time: 37.69s
#  Loss: 51.5200:
#  Recall@20: 0.1200
#  NDCG@20: 0.2592
# Epoch: 111, Training time: 165.12s, Loss: 50.6085
# Evaluate current model:
#  Epoch: 111, Validation time: 34.94s
#  Loss: 50.6085:
#  Recall@20: 0.1206
#  NDCG@20: 0.2604
# Epoch: 112, Training time: 162.83s, Loss: 50.4294
# Evaluate current model:
#  Epoch: 112, Validation time: 34.67s
#  Loss: 50.4294:
#  Recall@20: 0.1208
#  NDCG@20: 0.2588
# Epoch: 113, Training time: 166.19s, Loss: 49.4397
# Evaluate current model:
#  Epoch: 113, Validation time: 34.07s
#  Loss: 49.4397:
#  Recall@20: 0.1207
#  NDCG@20: 0.2598
# Epoch: 114, Training time: 162.81s, Loss: 49.2258
# Evaluate current model:
#  Epoch: 114, Validation time: 33.95s
#  Loss: 49.2258:
#  Recall@20: 0.1213
#  NDCG@20: 0.2606
# Epoch: 115, Training time: 162.74s, Loss: 48.5071
# Evaluate current model:
#  Epoch: 115, Validation time: 33.38s
#  Loss: 48.5071:
#  Recall@20: 0.1216
#  NDCG@20: 0.2612
# Epoch: 116, Training time: 163.81s, Loss: 48.4044
# Evaluate current model:
#  Epoch: 116, Validation time: 33.66s
#  Loss: 48.4044:
#  Recall@20: 0.1215
#  NDCG@20: 0.2611
# Epoch: 117, Training time: 161.54s, Loss: 47.6672
# Evaluate current model:
#  Epoch: 117, Validation time: 42.45s
#  Loss: 47.6672:
#  Recall@20: 0.1216
#  NDCG@20: 0.2608
# Epoch: 118, Training time: 160.95s, Loss: 46.9565
# Evaluate current model:
#  Epoch: 118, Validation time: 33.34s
#  Loss: 46.9565:
#  Recall@20: 0.1218
#  NDCG@20: 0.2619
# Epoch: 119, Training time: 160.16s, Loss: 46.9229
# Evaluate current model:
#  Epoch: 119, Validation time: 33.35s
#  Loss: 46.9229:
#  Recall@20: 0.1220
#  NDCG@20: 0.2625
# Epoch: 120, Training time: 162.85s, Loss: 46.0647
# Evaluate current model:
#  Epoch: 120, Validation time: 33.81s
#  Loss: 46.0647:
#  Recall@20: 0.1219
#  NDCG@20: 0.2622
# Epoch: 121, Training time: 162.89s, Loss: 45.5854
# Evaluate current model:
#  Epoch: 121, Validation time: 33.72s
#  Loss: 45.5854:
#  Recall@20: 0.1222
#  NDCG@20: 0.2626
# Epoch: 122, Training time: 162.34s, Loss: 45.3965
# Evaluate current model:
#  Epoch: 122, Validation time: 34.21s
#  Loss: 45.3965:
#  Recall@20: 0.1221
#  NDCG@20: 0.2624
# Epoch: 123, Training time: 161.95s, Loss: 44.4501
# Evaluate current model:
#  Epoch: 123, Validation time: 32.36s
#  Loss: 44.4501:
#  Recall@20: 0.1229
#  NDCG@20: 0.2623
# Epoch: 124, Training time: 164.55s, Loss: 44.0864
# Evaluate current model:
#  Epoch: 124, Validation time: 33.69s
#  Loss: 44.0864:
#  Recall@20: 0.1224
#  NDCG@20: 0.2622
# Epoch: 125, Training time: 164.22s, Loss: 43.7418
# Evaluate current model:
#  Epoch: 125, Validation time: 34.38s
#  Loss: 43.7418:
#  Recall@20: 0.1229
#  NDCG@20: 0.2627
# Epoch: 126, Training time: 163.68s, Loss: 43.4402
# Evaluate current model:
#  Epoch: 126, Validation time: 34.76s
#  Loss: 43.4402:
#  Recall@20: 0.1240
#  NDCG@20: 0.2635
# Epoch: 127, Training time: 163.98s, Loss: 42.8245
# Evaluate current model:
#  Epoch: 127, Validation time: 34.14s
#  Loss: 42.8245:
#  Recall@20: 0.1234
#  NDCG@20: 0.2641
# Epoch: 128, Training time: 161.93s, Loss: 42.6158
# Evaluate current model:
#  Epoch: 128, Validation time: 34.02s
#  Loss: 42.6158:
#  Recall@20: 0.1229
#  NDCG@20: 0.2635
# Epoch: 129, Training time: 163.81s, Loss: 41.8880
# Evaluate current model:
#  Epoch: 129, Validation time: 35.63s
#  Loss: 41.8880:
#  Recall@20: 0.1233
#  NDCG@20: 0.2636
# Epoch: 130, Training time: 166.61s, Loss: 41.9547
# Evaluate current model:
#  Epoch: 130, Validation time: 34.49s
#  Loss: 41.9547:
#  Recall@20: 0.1238
#  NDCG@20: 0.2641
# Epoch: 131, Training time: 165.72s, Loss: 41.1608
# Evaluate current model:
#  Epoch: 131, Validation time: 35.35s
#  Loss: 41.1608:
#  Recall@20: 0.1237
#  NDCG@20: 0.2648
# Early stopping at step: 5 log:0.12366867810487747
