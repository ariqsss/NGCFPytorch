# %%
import numpy as np
import random as rd
import scipy.sparse as sp
import torch
from time import time
import numpy as np
import scipy.sparse as sp
import torch
import torch.nn.functional as F
import scipy.sparse as sp
from torch import nn
import pandas as pd
import os
from datetime import datetime
from scipy.stats import truncnorm
from torch.autograd import Variable, grad
#from utils.load_data import Data
#from utils.parser import parse_args
#from utils.helper_functions import early_stopping,\
                                   #train,\
                                   #split_matrix,\
                                   #compute_ndcg_k,\
                                   #eval_model

# read parsed arguments
#args = parse_args()

#from google.colab import drive
#drive.mount('/content/drive')
#data_dir = '/content/drive/My Drive/Colab Notebooks/NGCFPytorch/data/'
data_dir = './data/'
dataset = 'Gowella'
batch_size = 1024
layers = eval('[64,64]')
emb_dim = 64
lr = 0.0001
reg = 1e-5
mess_dropout = 0.1
node_dropout = 0.
k = 20
argssave_results = 1
argsn_epochs = 200
argseval_N = 1

# %%
#torch.cuda.is_available()
#torch. __version__
#print(advloss)

# %% [markdown]
# #1

# %%
class Data(object):
    def __init__(self, path, batch_size):
        self.path = path
        self.batch_size = batch_size

        train_file = path + '/train.txt'
        test_file = path + '/test.txt'

        #get number of users and items
        self.n_users, self.n_items = 0, 0
        self.n_train, self.n_test = 0, 0
        self.neg_pools = {}

        self.exist_users = []

        # search train_file for max user_id/item_id
        with open(train_file) as f:
            for l in f.readlines():
                if len(l) > 0:
                    l = l.strip('\n').split(' ')
                    items = [int(i) for i in l[1:]]
                    # first element is the user_id, rest are items
                    uid = int(l[0])
                    self.exist_users.append(uid)
                    # item/user with highest number is number of items/users
                    self.n_items = max(self.n_items, max(items))
                    self.n_users = max(self.n_users, uid)
                    # number of interactions
                    self.n_train += len(items)

        # search test_file for max item_id
        with open(test_file) as f:
            for l in f.readlines():
                if len(l) > 0:
                    l = l.strip('\n')
                    try:
                        items = [int(i) for i in l.split(' ')[1:]]
                    except Exception:
                        continue
                    if not items:
                        print("empyt test exists")
                        pass
                    else:
                        self.n_items = max(self.n_items, max(items))
                        self.n_test += len(items)
        # adjust counters: user_id/item_id starts at 0
        self.n_items += 1
        self.n_users += 1

        self.print_statistics()

        # create interactions/ratings matrix 'R' # dok = dictionary of keys
        print('Creating interaction matrices R_train and R_test...')
        t1 = time()
        self.R_train = sp.dok_matrix((self.n_users, self.n_items), dtype=np.float32) 
        self.R_test = sp.dok_matrix((self.n_users, self.n_items), dtype=np.float32)

        self.train_items, self.test_set = {}, {}
        with open(train_file) as f_train:
            with open(test_file) as f_test:
                for l in f_train.readlines():
                    if len(l) == 0: break
                    l = l.strip('\n')
                    items = [int(i) for i in l.split(' ')]
                    uid, train_items = items[0], items[1:]
                    # enter 1 if user interacted with item
                    for i in train_items:
                        self.R_train[uid, i] = 1.
                    self.train_items[uid] = train_items

                for l in f_test.readlines():
                    if len(l) == 0: break
                    l = l.strip('\n')
                    try:
                        items = [int(i) for i in l.split(' ')]
                    except Exception:
                        continue
                    uid, test_items = items[0], items[1:]
                    for i in test_items:
                        self.R_test[uid, i] = 1.0
                    self.test_set[uid] = test_items
        print('Complete. Interaction matrices R_train and R_test created in', time() - t1, 'sec')

    # if exist, get adjacency matrix
    def get_adj_mat(self):
        try:
            t1 = time()
            adj_mat = sp.load_npz(self.path + '/s_adj_mat.npz')
            print('Loaded adjacency-matrix (shape:', adj_mat.shape,') in', time() - t1, 'sec.')

        except Exception:
            print('Creating adjacency-matrix...')
            adj_mat = self.create_adj_mat()
            sp.save_npz(self.path + '/s_adj_mat.npz', adj_mat)
        return adj_mat
    
    # create adjancency matrix
    def create_adj_mat(self):
        t1 = time()
        
        adj_mat = sp.dok_matrix((self.n_users + self.n_items, self.n_users + self.n_items), dtype=np.float32)
        adj_mat = adj_mat.tolil()
        R = self.R_train.tolil() # to list of lists

        adj_mat[:self.n_users, self.n_users:] = R
        adj_mat[self.n_users:, :self.n_users] = R.T
        adj_mat = adj_mat.todok()
        print('Complete. Adjacency-matrix created in', adj_mat.shape, time() - t1, 'sec.')

        t2 = time()

        # normalize adjacency matrix
        def normalized_adj_single(adj):
            rowsum = np.array(adj.sum(1))

            d_inv = np.power(rowsum, -.5).flatten()
            d_inv[np.isinf(d_inv)] = 0.
            d_mat_inv = sp.diags(d_inv)

            norm_adj = d_mat_inv.dot(adj).dot(d_mat_inv)
            return norm_adj.tocoo()

        print('Transforming adjacency-matrix to NGCF-adjacency matrix...')
        ngcf_adj_mat = normalized_adj_single(adj_mat) + sp.eye(adj_mat.shape[0])

        print('Complete. Transformed adjacency-matrix to NGCF-adjacency matrix in', time() - t2, 'sec.')
        return ngcf_adj_mat.tocsr()

    # create collections of N items that users never interacted with
    def negative_pool(self):
        t1 = time()
        for u in self.train_items.keys():
            neg_items = list(set(range(self.n_items)) - set(self.train_items[u]))
            pools = [rd.choice(neg_items) for _ in range(100)]
            self.neg_pools[u] = pools
        print('refresh negative pools', time() - t1)

    # sample data for mini-batches
    def sample(self):
        if self.batch_size <= self.n_users:
            users = rd.sample(self.exist_users, self.batch_size)
        else:
            users = [rd.choice(self.exist_users) for _ in range(self.batch_size)]

        def sample_pos_items_for_u(u, num):
            pos_items = self.train_items[u]
            n_pos_items = len(pos_items)
            pos_batch = []
            while True:
                if len(pos_batch) == num: break
                pos_id = np.random.randint(low=0, high=n_pos_items, size=1)[0]
                pos_i_id = pos_items[pos_id]

                if pos_i_id not in pos_batch:
                    pos_batch.append(pos_i_id)
            return pos_batch

        def sample_neg_items_for_u(u, num):
            neg_items = []
            while True:
                if len(neg_items) == num: break
                neg_id = np.random.randint(low=0, high=self.n_items,size=1)[0]
                if neg_id not in self.train_items[u] and neg_id not in neg_items:
                    neg_items.append(neg_id)
            return neg_items

        def sample_neg_items_for_u_from_pools(u, num):
            neg_items = list(set(self.neg_pools[u]) - set(self.train_items[u]))
            return rd.sample(neg_items, num)

        pos_items, neg_items = [], []
        for u in users:
            pos_items += sample_pos_items_for_u(u, 1)
            neg_items += sample_neg_items_for_u(u, 1)

        return users, pos_items, neg_items

    def get_num_users_items(self):
        return self.n_users, self.n_items

    def print_statistics(self):
        print('n_users=%d, n_items=%d' % (self.n_users, self.n_items))
        print('n_interactions=%d' % (self.n_train + self.n_test))
        print('n_train=%d, n_test=%d, sparsity=%.5f' % (self.n_train, self.n_test, (self.n_train + self.n_test)/(self.n_users * self.n_items)))

# %% [markdown]
# #2

# %%
def early_stopping(log_value, best_value, stopping_step, flag_step, expected_order='asc'):
    """
    Check if early_stopping is needed
    Function copied from original code
    """
    assert expected_order in ['asc', 'des']
    if (expected_order == 'asc' and log_value >= best_value) or (expected_order == 'des' and log_value <= best_value):
        stopping_step = 0
        best_value = log_value
    else:
        stopping_step += 1

    if stopping_step >= flag_step:
        print("Early stopping at step: {} log:{}".format(flag_step, log_value))
        should_stop = True
    else:
        should_stop = False

    return best_value, stopping_step, should_stop

def train(model, data_generator, optimizer):
    """
    Train the model PyTorch style

    Arguments:
    ---------
    model: PyTorch model
    data_generator: Data object
    optimizer: PyTorch optimizer
    """
    model.train()
    n_batch = data_generator.n_train // data_generator.batch_size + 1
    running_loss=0
    for _ in range(n_batch):
        u, i, j = data_generator.sample()
        optimizer.zero_grad()
        loss = model(u,i,j)
        loss.backward(retain_graph=True)
        optimizer.step()
        running_loss += loss.item()
    return running_loss

def split_matrix(X, n_splits=100):
    """
    Split a matrix/Tensor into n_folds (for the user embeddings and the R matrices)

    Arguments:
    ---------
    X: matrix to be split
    n_folds: number of folds

    Returns:
    -------
    splits: split matrices
    """
    splits = []
    chunk_size = X.shape[0] // n_splits
    for i in range(n_splits):
        start = i * chunk_size
        end = X.shape[0] if i == n_splits - 1 else (i + 1) * chunk_size
        splits.append(X[start:end])
    return splits

def compute_ndcg_k(pred_items, test_items, test_indices, k):
    """
    Compute NDCG@k
    
    Arguments:
    ---------
    pred_items: binary tensor with 1s in those locations corresponding to the predicted item interactions
    test_items: binary tensor with 1s in locations corresponding to the real test interactions
    test_indices: tensor with the location of the top-k predicted items
    k: k'th-order 

    Returns:
    -------
    NDCG@k
    """
    r = (test_items * pred_items).gather(1, test_indices)
    f = torch.from_numpy(np.log2(np.arange(2, k+2))).float().cuda()
    dcg = (r[:, :k]/f).sum(1)
    dcg_max = (torch.sort(r, dim=1, descending=True)[0][:, :k]/f).sum(1)
    ndcg = dcg/dcg_max
    ndcg[torch.isnan(ndcg)] = 0
    return ndcg


def eval_model(u_emb, i_emb, Rtr, Rte, k):
    """
    Evaluate the model
    
    Arguments:
    ---------
    u_emb: User embeddings
    i_emb: Item embeddings
    Rtr: Sparse matrix with the training interactions
    Rte: Sparse matrix with the testing interactions
    k : kth-order for metrics
    
    Returns:
    --------
    result: Dictionary with lists correponding to the metrics at order k for k in Ks
    """
    # split matrices
    ue_splits = split_matrix(u_emb)
    tr_splits = split_matrix(Rtr)
    te_splits = split_matrix(Rte)

    recall_k, ndcg_k= [], []
    # compute results for split matrices
    for ue_f, tr_f, te_f in zip(ue_splits, tr_splits, te_splits):

        scores = torch.mm(ue_f, i_emb.t())

        test_items = torch.from_numpy(te_f.todense()).float().cuda()
        non_train_items = torch.from_numpy(1-(tr_f.todense())).float().cuda()
        scores = scores * non_train_items

        _, test_indices = torch.topk(scores, dim=1, k=k)
        pred_items = torch.zeros_like(scores).float()
        #pred_items.scatter_(dim=1,index=test_indices,src=torch.tensor(1.0).cuda())
        pred_items.scatter_(dim=1, index=test_indices,src=torch.ones_like(test_indices).float().cuda())

        topk_preds = torch.zeros_like(scores).float()
        #topk_preds.scatter_(dim=1,index=test_indices[:, :k],src=torch.tensor(1.0))
        topk_preds.scatter_(dim=1, index=test_indices[:, :k], src=torch.ones_like(test_indices[:, :k]).float().cuda())

        TP = (test_items * topk_preds).sum(1)
        rec = TP/test_items.sum(1)
        ndcg = compute_ndcg_k(pred_items, test_items, test_indices, k)

        recall_k.append(rec)
        ndcg_k.append(ndcg)

    return torch.cat(recall_k).mean(), torch.cat(ndcg_k).mean()

# %% [markdown]
# #3

# %%
#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#print(device)
class NGCF(nn.Module):
    def __init__(self, n_users, n_items, emb_dim, layers, reg, node_dropout, mess_dropout,
        adj_mtx):
        super().__init__()

        # initialize Class attributes
        self.n_users = n_users
        self.n_items = n_items
        self.emb_dim = emb_dim
        self.adj_mtx = adj_mtx
        self.laplacian = adj_mtx - sp.eye(adj_mtx.shape[0])
        self.reg = reg
        self.layers = layers
        self.n_layers = len(self.layers)
        print(self.n_layers)
        self.node_dropout = node_dropout
        self.mess_dropout = mess_dropout
        self.u_g_embeddings = nn.Parameter(torch.empty(n_users, emb_dim+np.sum(self.layers)))
        self.i_g_embeddings = nn.Parameter(torch.empty(n_items, emb_dim+np.sum(self.layers)))
        self.nowepoch = 0
       # x = torch.zeros(1, 1, requires_grad=True)
        #print(x)
        self.advloss = torch.zeros(1, 1, requires_grad=True)
        
       # self.delta_P = tf.Variable(tf.zeros(shape=[self.num_users, self.embedding_size]),
                          #         name='delta_P', dtype=tf.float32, trainable=False)  # (users, embedding_size)
        #self.delta_P = nn.Parameter(torch.zeros([n_users, emb_dim+np.sum(self.layers)]),requires_grad=False)
        self.delta_P = nn.Parameter(torch.zeros([n_users, emb_dim+np.sum(self.layers)]).to(device),requires_grad=False)
        
       # self.delta_Qpos = tf.Variable(tf.zeros(shape=[self.num_items, self.embedding_size]),
                           #            name='delta_Q', dtype=tf.float32, trainable=False)  # (items, embedding_size)
        self.delta_Qpos = nn.Parameter(torch.zeros([n_items,emb_dim+np.sum(self.layers)]).to(device),requires_grad=False)
        #self.delta_Qneg = tf.Variable(tf.zeros(shape=[self.num_items, self.embedding_size]),
         #                              name='delta_Q', dtype=tf.float32, trainable=False)  # (items, embedding_size)
        self.delta_Qneg = nn.Parameter(torch.zeros([n_items,emb_dim+np.sum(self.layers)]).to(device),requires_grad=False)

        #self.h = tf.constant(1.0, tf.float32, [emb_dim, 1], name="h")
        #self.h = torch.tensor
        self.h = torch.ones([emb_dim, 1], dtype=torch.float64, device=device)

        # Initialize weights
        self.weight_dict = self._init_weights()
        print("Weights initialized.")

        # Create Matrix 'A', PyTorch sparse tensor of SP adjacency_mtx
        self.A = self._convert_sp_mat_to_sp_tensor(self.adj_mtx)
        self.L = self._convert_sp_mat_to_sp_tensor(self.laplacian)
        
    # initialize weights
    def _init_weights(self):
        print("Initializing weights...")
        weight_dict = nn.ParameterDict()

        initializer = torch.nn.init.xavier_uniform_
        
        weight_dict['user_embedding'] = nn.Parameter(initializer(torch.empty(self.n_users, self.emb_dim).to(device)))
        weight_dict['item_embedding'] = nn.Parameter(initializer(torch.empty(self.n_items, self.emb_dim).to(device)))

        weight_size_list = [self.emb_dim] + self.layers

        for k in range(self.n_layers):
            weight_dict['W_gc_%d' %k] = nn.Parameter(initializer(torch.empty(weight_size_list[k], weight_size_list[k+1]).to(device)))
            weight_dict['b_gc_%d' %k] = nn.Parameter(initializer(torch.empty(1, weight_size_list[k+1]).to(device)))
            
            weight_dict['W_bi_%d' %k] = nn.Parameter(initializer(torch.empty(weight_size_list[k], weight_size_list[k+1]).to(device)))
            weight_dict['b_bi_%d' %k] = nn.Parameter(initializer(torch.empty(1, weight_size_list[k+1]).to(device)))
           
        return weight_dict

    # convert sparse matrix into sparse PyTorch tensor
    def _convert_sp_mat_to_sp_tensor(self, X):
        """
        Convert scipy sparse matrix to PyTorch sparse matrix

        Arguments:
        ----------
        X = Adjacency matrix, scipy sparse matrix
        """
        coo = X.tocoo().astype(np.float32)
        i = torch.LongTensor(np.mat([coo.row, coo.col]))
        v = torch.FloatTensor(coo.data)
        res = torch.sparse.FloatTensor(i, v, coo.shape).to(device)
        return res

    # apply node_dropout
    def _droupout_sparse(self, X):
        """
        Drop individual locations in X
        
        Arguments:
        ---------
        X = adjacency matrix (PyTorch sparse tensor)
        dropout = fraction of nodes to drop
        noise_shape = number of non non-zero entries of X
        """
        
        node_dropout_mask = ((self.node_dropout) + torch.rand(X._nnz())).floor().bool().to(device)
        i = X.coalesce().indices()
        v = X.coalesce()._values()
        i[:,node_dropout_mask] = 0
        v[node_dropout_mask] = 0
        X_dropout = torch.sparse.FloatTensor(i, v, X.shape).to(X.device)

        return  X_dropout.mul(1/(1-self.node_dropout))
    
    def _create_adversarial(self):
       
        # generate the adversarial weights by random method
        # generation
        #self.adv_P = tf.truncated_normal(shape=[self.num_users, self.embedding_size], mean=0.0, stddev=0.01)
        self.adv_P = truncnorm.rvs(-0.01,0.01,size=[n_users,emb_dim])
        #self.adv_Q = tf.truncated_normal(shape=[self.num_items, self.embedding_size], mean=0.0, stddev=0.01)
        self.adv_Q = truncnorm.rvs(-0.01,0.01,size=[n_users,emb_dim])
        # normalization and multiply epsilon
        self.update_P = self.delta_P.assign(torch.nn.functional.normalize(self.adv_P, p=2, dim=1) * 0.5)
        self.update_Q = self.delta_Q.assign(torch.nn.functional.normalize(self.adv_P, p=2, dim=1) * 0.5)

    def forward(self, u, i, j):
        """
        Computes the forward pass
        
        Arguments:
        ---------
        u = user
        i = positive item (user interacted with item)
        j = negative item (user did not interact with item)
        """
        # apply drop-out mask
        A_hat = self._droupout_sparse(self.A) if self.node_dropout > 0 else self.A
        L_hat = self._droupout_sparse(self.L) if self.node_dropout > 0 else self.L

        ego_embeddings = torch.cat([self.weight_dict['user_embedding'], self.weight_dict['item_embedding']], 0)

        all_embeddings = [ego_embeddings]

        # forward pass for 'n' propagation layers
        for k in range(self.n_layers):

            # weighted sum messages of neighbours
            side_embeddings = torch.sparse.mm(A_hat, ego_embeddings)
            side_L_embeddings = torch.sparse.mm(L_hat, ego_embeddings)

            # transformed sum weighted sum messages of neighbours
            sum_embeddings = torch.matmul(side_embeddings, self.weight_dict['W_gc_%d' % k]) + self.weight_dict['b_gc_%d' % k]

            # bi messages of neighbours
            bi_embeddings = torch.mul(ego_embeddings, side_L_embeddings)
            # transformed bi messages of neighbours
            bi_embeddings = torch.matmul(bi_embeddings, self.weight_dict['W_bi_%d' % k]) + self.weight_dict['b_bi_%d' % k]

            # non-linear activation 
            ego_embeddings = F.leaky_relu(sum_embeddings + bi_embeddings)
            # + message dropout
            mess_dropout_mask = nn.Dropout(self.mess_dropout)
            ego_embeddings = mess_dropout_mask(ego_embeddings)

            # normalize activation
            norm_embeddings = F.normalize(ego_embeddings, p=2, dim=1)

            all_embeddings.append(norm_embeddings)

        all_embeddings = torch.cat(all_embeddings, 1)
        ###RANDOM
        #self.adv_P = torch.from_numpy(truncnorm.rvs(-0.01,0.01,size=[batch_size,emb_dim+np.sum(self.layers)]))
        #t = torch.from_numpy(a)
        #self.adv_Q = torch.from_numpy(truncnorm.rvs(-0.01,0.01,size=[batch_size,emb_dim+np.sum(self.layers)]))
        #t = torch.from_numpy(a)
        
       
        
        
        # back to user/item dimension
        u_g_embeddings, i_g_embeddings = all_embeddings.split([self.n_users, self.n_items], 0)
       # print("sebelum perturbation")
        #print(u_g_embeddings)
       # print(self.nowepoch)
        if self.nowepoch > 120:
            u_g_embeddings = u_g_embeddings + self.delta_P
       # print("adversarial perturbation")
        #print(self.delta_P)
        #print("setelah perturbation")
        #print(u_g_embeddings)
            i_g_embeddings =  i_g_embeddings + self.delta_Qpos
            #print("adversarial added\n")
        self.u_g_embeddings = nn.Parameter(u_g_embeddings.float())
        self.i_g_embeddings = nn.Parameter(i_g_embeddings)
        #print(self.u_g_embeddings.size())
        #print(self.delta_P.size())
         ##Adversarial
       
           
        #self.advloss.requires_grad=True
       
        
        #u_g_embeddings = u_g_embeddings + self.delta_P
       # print(u_g_embeddings.size())
       #print(self.delta_P.size())
        u_emb = u_g_embeddings[u] #+ torch.sum(self.delta_P, 1)# user embeddings
       # print("embedding awal")
       # print(u_emb)
       # print("\n\n perturbation random")
       # print(self.delta_P)
       # print("embedding setelah perturbation\n\n")
        u_emb = u_emb 
        #print(u_emb)
        p_emb = i_g_embeddings[i] #+ torch.sum(torch.nn.Embedding(self.i_placeholder,emb_dim, _weight=self.delta_Qpos), 1) # positive item embeddings
        #p_emb = p_emb + self.delta_Qpos
        
        n_emb = i_g_embeddings[j]# + torch.sum(torch.nn.Embedding(self.i_placeholder,emb_dim, _weight=self.delta_Qneg), 1)# negative item embeddings
       # n_emb = n_emb + self.delta_Qneg
        #print(u_emb.size())
        #print(p_emb.size())
        #print(n_emb)
        y_ui = torch.mul(u_emb, p_emb).sum(dim=1)
        y_uj = torch.mul(u_emb, n_emb).sum(dim=1)
        self.advloss = (torch.log(torch.sigmoid(y_ui-y_uj))).mean()
        #print(y_ui)
        #print(y_uj)
        #print(log_prob)
        if self.nowepoch > 120:
            self.adv_P, self.adv_Q = torch.autograd.grad(self.advloss, [u_g_embeddings, i_g_embeddings],torch.ones_like(self.advloss), retain_graph=True)
            self.adv_P_dense = self.adv_P.detach()
            self.adv_Q_dense = self.adv_Q.detach()
        
       # print(self.adv_P_dense)
       # print(self.adv_Q_dense)
       # print(self.adv_P_dense.size())
       # print(self.adv_Q_dense.size())
            self.delta_P = nn.Parameter(torch.nn.functional.normalize(self.adv_P_dense, p=2, dim=1).to(device) * 0.5)
            self.delta_Qpos = nn.Parameter(torch.nn.functional.normalize(self.adv_Q_dense, p=2, dim=1).to(device) * 0.5)
            self.delta_Qneg = nn.Parameter(torch.nn.functional.normalize(self.adv_Q_dense, p=2, dim=1).to(device) * 0.5)

        # compute bpr-loss
        bpr_loss = -self.advloss
        if self.reg > 0.:
            l2norm = (torch.sum(u_emb**2)/2. + torch.sum(p_emb**2)/2. + torch.sum(n_emb**2)/2.) / u_emb.shape[0]
            l2reg  = self.reg*l2norm
            bpr_loss =  -self.advloss + l2reg
        #self.nowepoch +=1
        return bpr_loss

# %% [markdown]
# #4

# %%
#from ngcf import NGCF

use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.cuda.set_device(0)



# generate the NGCF-adjacency matrix
data_generator = Data(path=data_dir + dataset, batch_size=batch_size)
adj_mtx = data_generator.get_adj_mat()

# create model name and save
modelname =  "NGCF" + \
    "_bs_" + str(batch_size) + \
    "_nemb_" + str(emb_dim) + \
    "_layers_" + str(layers) + \
    "_nodedr_" + str(node_dropout) + \
    "_messdr_" + str(mess_dropout) + \
    "_reg_" + str(reg) + \
    "_lr_"  + str(lr)

# create NGCF model
model = NGCF(data_generator.n_users, 
              data_generator.n_items,
              emb_dim,
              layers,
              reg,
              node_dropout,
              mess_dropout,
              adj_mtx)
if use_cuda:
    model = model.cuda()

# current best metric
cur_best_metric = 0

# Adam optimizer
optimizer = torch.optim.Adam(model.parameters(), lr)

# Set values for early stopping
cur_best_loss, stopping_step, should_stop = 1e3, 0, False
today = datetime.now()

print("Start at " + str(today))
print("Using " + str(device) + " for computations")
print("Params on CUDA: " + str(next(model.parameters()).is_cuda))

results = {"Epoch": [],
            "Loss": [],
            "Recall": [],
            "NDCG": [],
            "Training Time": []}

for epoch in range(argsn_epochs):

    t1 = time()
    loss = train(model, data_generator, optimizer)
    training_time = time()-t1
    model.nowepoch += 1
    print("Epoch: {}, Training time: {:.2f}s, Loss: {:.4f}".
        format(epoch, training_time, loss))

    # print test evaluation metrics every N epochs (provided by args.eval_N)
    if epoch % argseval_N  == (argseval_N - 1):
        with torch.no_grad():
            t2 = time()
            recall, ndcg = eval_model(model.u_g_embeddings.detach(),
                                      model.i_g_embeddings.detach(),
                                      data_generator.R_train,
                                      data_generator.R_test,
                                      k)
        print(
            "Evaluate current model:\n",
            "Epoch: {}, Validation time: {:.2f}s".format(epoch, time()-t2),"\n",
            "Loss: {:.4f}:".format(loss), "\n",
            "Recall@{}: {:.4f}".format(k, recall), "\n",
            "NDCG@{}: {:.4f}".format(k, ndcg)
            )

        cur_best_metric, stopping_step, should_stop = \
        early_stopping(recall, cur_best_metric, stopping_step, flag_step=50)

        # save results in dict
        results['Epoch'].append(epoch)
        results['Loss'].append(loss)
        results['Recall'].append(recall.item())
        results['NDCG'].append(ndcg.item())
        results['Training Time'].append(training_time)
    else:
        # save results in dict
        results['Epoch'].append(epoch)
        results['Loss'].append(loss)
        results['Recall'].append(None)
        results['NDCG'].append(None)
        results['Training Time'].append(training_time)

    if should_stop == True: break

# save
if argssave_results:
    date = today.strftime("%d%m%Y_%H%M")

    # save model as .pt file
    if os.path.isdir("./models"):
        torch.save(model.state_dict(), "./models/" + str(date) + "_" + modelname + "_" + dataset + ".pt")
    else:
        os.mkdir("./models")
        torch.save(model.state_dict(), "./models/" + str(date) + "_" + modelname + "_" + dataset + ".pt")

    # save results as pandas dataframe
    results_df = pd.DataFrame(results)
    results_df.set_index('Epoch', inplace=True)
    if os.path.isdir("./results"):
        results_df.to_csv("./results/" + str(date) + "_" + modelname + "_" + dataset + ".csv")
    else:
        os.mkdir("./results")
        results_df.to_csv("./results/" + str(date) + "_" + modelname + "_" + dataset + ".csv")
    # plot loss
    results_df['Loss'].plot(figsize=(12,8), title='Loss')
# Out:
# n_users=29858, n_items=40981
# n_interactions=1027370
# n_train=810128, n_test=217242, sparsity=0.00084
# Creating interaction matrices R_train and R_test...
# Complete. Interaction matrices R_train and R_test created in 10.538992643356323 sec
# Loaded adjacency-matrix (shape: (70839, 70839) ) in 0.09199929237365723 sec.
# 2
# Initializing weights...
# Weights initialized.
# Start at 2022-06-09 23:16:51.502776
# Using cuda for computations
# Params on CUDA: True
# Epoch: 0, Training time: 159.23s, Loss: 503.7629
# Evaluate current model:
#  Epoch: 0, Validation time: 33.04s
#  Loss: 503.7629:
#  Recall@20: 0.0016
#  NDCG@20: 0.0058
# Epoch: 1, Training time: 159.21s, Loss: 402.3847
# Evaluate current model:
#  Epoch: 1, Validation time: 32.93s
#  Loss: 402.3847:
#  Recall@20: 0.0022
#  NDCG@20: 0.0076
# Epoch: 2, Training time: 159.23s, Loss: 349.2268
# Evaluate current model:
#  Epoch: 2, Validation time: 32.79s
#  Loss: 349.2268:
#  Recall@20: 0.0031
#  NDCG@20: 0.0092
# Epoch: 3, Training time: 160.31s, Loss: 313.9351
# Evaluate current model:
#  Epoch: 3, Validation time: 33.35s
#  Loss: 313.9351:
#  Recall@20: 0.0055
#  NDCG@20: 0.0146
# Epoch: 4, Training time: 166.92s, Loss: 288.4170
# Evaluate current model:
#  Epoch: 4, Validation time: 36.01s
#  Loss: 288.4170:
#  Recall@20: 0.0081
#  NDCG@20: 0.0202
# Epoch: 5, Training time: 160.03s, Loss: 274.9953
# Evaluate current model:
#  Epoch: 5, Validation time: 32.96s
#  Loss: 274.9953:
#  Recall@20: 0.0143
#  NDCG@20: 0.0362
# Epoch: 6, Training time: 159.21s, Loss: 265.4384
# Evaluate current model:
#  Epoch: 6, Validation time: 33.26s
#  Loss: 265.4384:
#  Recall@20: 0.0169
#  NDCG@20: 0.0380
# Epoch: 7, Training time: 159.28s, Loss: 253.3395
# Evaluate current model:
#  Epoch: 7, Validation time: 32.73s
#  Loss: 253.3395:
#  Recall@20: 0.0211
#  NDCG@20: 0.0503
# Epoch: 8, Training time: 159.22s, Loss: 240.5797
# Evaluate current model:
#  Epoch: 8, Validation time: 32.65s
#  Loss: 240.5797:
#  Recall@20: 0.0276
#  NDCG@20: 0.0607
# Epoch: 9, Training time: 159.24s, Loss: 229.6125
# Evaluate current model:
#  Epoch: 9, Validation time: 32.62s
#  Loss: 229.6125:
#  Recall@20: 0.0301
#  NDCG@20: 0.0663
# Epoch: 10, Training time: 159.33s, Loss: 219.9386
# Evaluate current model:
#  Epoch: 10, Validation time: 32.54s
#  Loss: 219.9386:
#  Recall@20: 0.0325
#  NDCG@20: 0.0734
# Epoch: 11, Training time: 159.22s, Loss: 212.2180
# Evaluate current model:
#  Epoch: 11, Validation time: 32.76s
#  Loss: 212.2180:
#  Recall@20: 0.0329
#  NDCG@20: 0.0750
# Epoch: 12, Training time: 159.18s, Loss: 205.9913
# Evaluate current model:
#  Epoch: 12, Validation time: 32.50s
#  Loss: 205.9913:
#  Recall@20: 0.0339
#  NDCG@20: 0.0753
# Epoch: 13, Training time: 159.30s, Loss: 201.0310
# Evaluate current model:
#  Epoch: 13, Validation time: 32.83s
#  Loss: 201.0310:
#  Recall@20: 0.0365
#  NDCG@20: 0.0824
# Epoch: 14, Training time: 159.19s, Loss: 196.3932
# Evaluate current model:
#  Epoch: 14, Validation time: 32.74s
#  Loss: 196.3932:
#  Recall@20: 0.0371
#  NDCG@20: 0.0805
# Epoch: 15, Training time: 159.20s, Loss: 192.3304
# Evaluate current model:
#  Epoch: 15, Validation time: 32.64s
#  Loss: 192.3304:
#  Recall@20: 0.0398
#  NDCG@20: 0.0890
# Epoch: 16, Training time: 159.29s, Loss: 189.4993
# Evaluate current model:
#  Epoch: 16, Validation time: 32.96s
#  Loss: 189.4993:
#  Recall@20: 0.0409
#  NDCG@20: 0.0886
# Epoch: 17, Training time: 159.24s, Loss: 187.0328
# Evaluate current model:
#  Epoch: 17, Validation time: 32.65s
#  Loss: 187.0328:
#  Recall@20: 0.0427
#  NDCG@20: 0.0938
# Epoch: 18, Training time: 159.32s, Loss: 184.2662
# Evaluate current model:
#  Epoch: 18, Validation time: 32.68s
#  Loss: 184.2662:
#  Recall@20: 0.0448
#  NDCG@20: 0.0944
# Epoch: 19, Training time: 159.29s, Loss: 181.9959
# Evaluate current model:
#  Epoch: 19, Validation time: 32.79s
#  Loss: 181.9959:
#  Recall@20: 0.0461
#  NDCG@20: 0.0980
# Epoch: 20, Training time: 159.21s, Loss: 180.5632
# Evaluate current model:
#  Epoch: 20, Validation time: 32.52s
#  Loss: 180.5632:
#  Recall@20: 0.0473
#  NDCG@20: 0.0995
# Epoch: 21, Training time: 159.24s, Loss: 178.1147
# Evaluate current model:
#  Epoch: 21, Validation time: 32.73s
#  Loss: 178.1147:
#  Recall@20: 0.0491
#  NDCG@20: 0.1047
# Epoch: 22, Training time: 159.29s, Loss: 176.2315
# Evaluate current model:
#  Epoch: 22, Validation time: 32.57s
#  Loss: 176.2315:
#  Recall@20: 0.0506
#  NDCG@20: 0.1102
# Epoch: 23, Training time: 159.29s, Loss: 174.5925
# Evaluate current model:
#  Epoch: 23, Validation time: 32.70s
#  Loss: 174.5925:
#  Recall@20: 0.0527
#  NDCG@20: 0.1145
# Epoch: 24, Training time: 159.21s, Loss: 172.9826
# Evaluate current model:
#  Epoch: 24, Validation time: 32.79s
#  Loss: 172.9826:
#  Recall@20: 0.0555
#  NDCG@20: 0.1223
# Epoch: 25, Training time: 159.28s, Loss: 171.6561
# Evaluate current model:
#  Epoch: 25, Validation time: 32.73s
#  Loss: 171.6561:
#  Recall@20: 0.0549
#  NDCG@20: 0.1195
# Epoch: 26, Training time: 159.36s, Loss: 169.2511
# Evaluate current model:
#  Epoch: 26, Validation time: 32.68s
#  Loss: 169.2511:
#  Recall@20: 0.0594
#  NDCG@20: 0.1318
# Epoch: 27, Training time: 159.61s, Loss: 167.5557
# Evaluate current model:
#  Epoch: 27, Validation time: 32.54s
#  Loss: 167.5557:
#  Recall@20: 0.0606
#  NDCG@20: 0.1343
# Epoch: 28, Training time: 159.30s, Loss: 165.6683
# Evaluate current model:
#  Epoch: 28, Validation time: 32.74s
#  Loss: 165.6683:
#  Recall@20: 0.0637
#  NDCG@20: 0.1406
# Epoch: 29, Training time: 159.31s, Loss: 163.6083
# Evaluate current model:
#  Epoch: 29, Validation time: 32.70s
#  Loss: 163.6083:
#  Recall@20: 0.0664
#  NDCG@20: 0.1467
# Epoch: 30, Training time: 159.25s, Loss: 162.1938
# Evaluate current model:
#  Epoch: 30, Validation time: 32.60s
#  Loss: 162.1938:
#  Recall@20: 0.0697
#  NDCG@20: 0.1555
# Epoch: 31, Training time: 159.28s, Loss: 160.2001
# Evaluate current model:
#  Epoch: 31, Validation time: 33.36s
#  Loss: 160.2001:
#  Recall@20: 0.0716
#  NDCG@20: 0.1584
# Epoch: 32, Training time: 159.29s, Loss: 158.6219
# Evaluate current model:
#  Epoch: 32, Validation time: 32.57s
#  Loss: 158.6219:
#  Recall@20: 0.0744
#  NDCG@20: 0.1693
# Epoch: 33, Training time: 159.32s, Loss: 156.9052
# Evaluate current model:
#  Epoch: 33, Validation time: 32.68s
#  Loss: 156.9052:
#  Recall@20: 0.0756
#  NDCG@20: 0.1702
# Epoch: 34, Training time: 159.16s, Loss: 155.2118
# Evaluate current model:
#  Epoch: 34, Validation time: 32.79s
#  Loss: 155.2118:
#  Recall@20: 0.0792
#  NDCG@20: 0.1784
# Epoch: 35, Training time: 159.37s, Loss: 153.5432
# Evaluate current model:
#  Epoch: 35, Validation time: 32.59s
#  Loss: 153.5432:
#  Recall@20: 0.0795
#  NDCG@20: 0.1773
# Epoch: 36, Training time: 159.30s, Loss: 151.9715
# Evaluate current model:
#  Epoch: 36, Validation time: 32.69s
#  Loss: 151.9715:
#  Recall@20: 0.0823
#  NDCG@20: 0.1831
# Epoch: 37, Training time: 159.25s, Loss: 149.9888
# Evaluate current model:
#  Epoch: 37, Validation time: 32.52s
#  Loss: 149.9888:
#  Recall@20: 0.0834
#  NDCG@20: 0.1894
# Epoch: 38, Training time: 159.25s, Loss: 148.2739
# Evaluate current model:
#  Epoch: 38, Validation time: 32.64s
#  Loss: 148.2739:
#  Recall@20: 0.0852
#  NDCG@20: 0.1897
# Epoch: 39, Training time: 159.24s, Loss: 146.4967
# Evaluate current model:
#  Epoch: 39, Validation time: 32.74s
#  Loss: 146.4967:
#  Recall@20: 0.0871
#  NDCG@20: 0.1943
# Epoch: 40, Training time: 159.26s, Loss: 144.4751
# Evaluate current model:
#  Epoch: 40, Validation time: 32.72s
#  Loss: 144.4751:
#  Recall@20: 0.0896
#  NDCG@20: 0.1992
# Epoch: 41, Training time: 159.45s, Loss: 142.5985
# Evaluate current model:
#  Epoch: 41, Validation time: 32.70s
#  Loss: 142.5985:
#  Recall@20: 0.0913
#  NDCG@20: 0.2036
# Epoch: 42, Training time: 159.21s, Loss: 140.8696
# Evaluate current model:
#  Epoch: 42, Validation time: 32.63s
#  Loss: 140.8696:
#  Recall@20: 0.0929
#  NDCG@20: 0.2077
# Epoch: 43, Training time: 159.25s, Loss: 138.9942
# Evaluate current model:
#  Epoch: 43, Validation time: 32.56s
#  Loss: 138.9942:
#  Recall@20: 0.0933
#  NDCG@20: 0.2082
# Epoch: 44, Training time: 159.30s, Loss: 137.4382
# Evaluate current model:
#  Epoch: 44, Validation time: 32.52s
#  Loss: 137.4382:
#  Recall@20: 0.0951
#  NDCG@20: 0.2100
# Epoch: 45, Training time: 159.28s, Loss: 135.3046
# Evaluate current model:
#  Epoch: 45, Validation time: 32.57s
#  Loss: 135.3046:
#  Recall@20: 0.0962
#  NDCG@20: 0.2121
# Epoch: 46, Training time: 159.53s, Loss: 133.8867
# Evaluate current model:
#  Epoch: 46, Validation time: 32.88s
#  Loss: 133.8867:
#  Recall@20: 0.0960
#  NDCG@20: 0.2141
# Epoch: 47, Training time: 159.29s, Loss: 131.5844
# Evaluate current model:
#  Epoch: 47, Validation time: 33.00s
#  Loss: 131.5844:
#  Recall@20: 0.0969
#  NDCG@20: 0.2161
# Epoch: 48, Training time: 159.15s, Loss: 129.8552
# Evaluate current model:
#  Epoch: 48, Validation time: 32.90s
#  Loss: 129.8552:
#  Recall@20: 0.0985
#  NDCG@20: 0.2170
# Epoch: 49, Training time: 159.34s, Loss: 128.0317
# Evaluate current model:
#  Epoch: 49, Validation time: 32.87s
#  Loss: 128.0317:
#  Recall@20: 0.1000
#  NDCG@20: 0.2214
# Epoch: 50, Training time: 159.34s, Loss: 126.3173
# Evaluate current model:
#  Epoch: 50, Validation time: 32.99s
#  Loss: 126.3173:
#  Recall@20: 0.0989
#  NDCG@20: 0.2196
# Epoch: 51, Training time: 159.21s, Loss: 124.2893
# Evaluate current model:
#  Epoch: 51, Validation time: 32.99s
#  Loss: 124.2893:
#  Recall@20: 0.1010
#  NDCG@20: 0.2236
# Epoch: 52, Training time: 159.31s, Loss: 122.3465
# Evaluate current model:
#  Epoch: 52, Validation time: 32.88s
#  Loss: 122.3465:
#  Recall@20: 0.1017
#  NDCG@20: 0.2244
# Epoch: 53, Training time: 159.22s, Loss: 120.8756
# Evaluate current model:
#  Epoch: 53, Validation time: 32.95s
#  Loss: 120.8756:
#  Recall@20: 0.1025
#  NDCG@20: 0.2256
# Epoch: 54, Training time: 159.30s, Loss: 118.9662
# Evaluate current model:
#  Epoch: 54, Validation time: 32.88s
#  Loss: 118.9662:
#  Recall@20: 0.1029
#  NDCG@20: 0.2266
# Epoch: 55, Training time: 159.37s, Loss: 116.8223
# Evaluate current model:
#  Epoch: 55, Validation time: 33.13s
#  Loss: 116.8223:
#  Recall@20: 0.1042
#  NDCG@20: 0.2274
# Epoch: 56, Training time: 159.32s, Loss: 115.5913
# Evaluate current model:
#  Epoch: 56, Validation time: 33.10s
#  Loss: 115.5913:
#  Recall@20: 0.1046
#  NDCG@20: 0.2305
# Epoch: 57, Training time: 159.28s, Loss: 113.4208
# Evaluate current model:
#  Epoch: 57, Validation time: 32.87s
#  Loss: 113.4208:
#  Recall@20: 0.1048
#  NDCG@20: 0.2295
# Epoch: 58, Training time: 159.20s, Loss: 111.7997
# Evaluate current model:
#  Epoch: 58, Validation time: 32.88s
#  Loss: 111.7997:
#  Recall@20: 0.1053
#  NDCG@20: 0.2315
# Epoch: 59, Training time: 159.18s, Loss: 110.2940
# Evaluate current model:
#  Epoch: 59, Validation time: 32.75s
#  Loss: 110.2940:
#  Recall@20: 0.1059
#  NDCG@20: 0.2324
# Epoch: 60, Training time: 159.23s, Loss: 108.6628
# Evaluate current model:
#  Epoch: 60, Validation time: 33.20s
#  Loss: 108.6628:
#  Recall@20: 0.1066
#  NDCG@20: 0.2333
# Epoch: 61, Training time: 159.26s, Loss: 107.0429
# Evaluate current model:
#  Epoch: 61, Validation time: 34.37s
#  Loss: 107.0429:
#  Recall@20: 0.1067
#  NDCG@20: 0.2357
# Epoch: 62, Training time: 159.24s, Loss: 105.4529
# Evaluate current model:
#  Epoch: 62, Validation time: 32.99s
#  Loss: 105.4529:
#  Recall@20: 0.1069
#  NDCG@20: 0.2347
# Epoch: 63, Training time: 159.28s, Loss: 104.1310
# Evaluate current model:
#  Epoch: 63, Validation time: 32.76s
#  Loss: 104.1310:
#  Recall@20: 0.1074
#  NDCG@20: 0.2344
# Epoch: 64, Training time: 159.21s, Loss: 101.9646
# Evaluate current model:
#  Epoch: 64, Validation time: 32.90s
#  Loss: 101.9646:
#  Recall@20: 0.1080
#  NDCG@20: 0.2367
# Epoch: 65, Training time: 159.25s, Loss: 100.4504
# Evaluate current model:
#  Epoch: 65, Validation time: 32.92s
#  Loss: 100.4504:
#  Recall@20: 0.1091
#  NDCG@20: 0.2384
# Epoch: 66, Training time: 159.24s, Loss: 99.5827
# Evaluate current model:
#  Epoch: 66, Validation time: 33.05s
#  Loss: 99.5827:
#  Recall@20: 0.1089
#  NDCG@20: 0.2377
# Epoch: 67, Training time: 159.23s, Loss: 97.9047
# Evaluate current model:
#  Epoch: 67, Validation time: 33.05s
#  Loss: 97.9047:
#  Recall@20: 0.1095
#  NDCG@20: 0.2385
# Epoch: 68, Training time: 159.23s, Loss: 96.4037
# Evaluate current model:
#  Epoch: 68, Validation time: 33.03s
#  Loss: 96.4037:
#  Recall@20: 0.1102
#  NDCG@20: 0.2415
# Epoch: 69, Training time: 159.30s, Loss: 95.0785
# Evaluate current model:
#  Epoch: 69, Validation time: 32.94s
#  Loss: 95.0785:
#  Recall@20: 0.1102
#  NDCG@20: 0.2405
# Epoch: 70, Training time: 159.25s, Loss: 93.8175
# Evaluate current model:
#  Epoch: 70, Validation time: 32.91s
#  Loss: 93.8175:
#  Recall@20: 0.1107
#  NDCG@20: 0.2414
# Epoch: 71, Training time: 159.29s, Loss: 92.0469
# Evaluate current model:
#  Epoch: 71, Validation time: 33.08s
#  Loss: 92.0469:
#  Recall@20: 0.1112
#  NDCG@20: 0.2421
# Epoch: 72, Training time: 159.31s, Loss: 90.9653
# Evaluate current model:
#  Epoch: 72, Validation time: 33.08s
#  Loss: 90.9653:
#  Recall@20: 0.1110
#  NDCG@20: 0.2424
# Epoch: 73, Training time: 159.27s, Loss: 89.8454
# Evaluate current model:
#  Epoch: 73, Validation time: 33.12s
#  Loss: 89.8454:
#  Recall@20: 0.1119
#  NDCG@20: 0.2429
# Epoch: 74, Training time: 159.24s, Loss: 88.4628
# Evaluate current model:
#  Epoch: 74, Validation time: 33.28s
#  Loss: 88.4628:
#  Recall@20: 0.1117
#  NDCG@20: 0.2442
# Epoch: 75, Training time: 159.21s, Loss: 87.4450
# Evaluate current model:
#  Epoch: 75, Validation time: 33.43s
#  Loss: 87.4450:
#  Recall@20: 0.1127
#  NDCG@20: 0.2451
# Epoch: 76, Training time: 159.25s, Loss: 86.3895
# Evaluate current model:
#  Epoch: 76, Validation time: 33.11s
#  Loss: 86.3895:
#  Recall@20: 0.1127
#  NDCG@20: 0.2442
# Epoch: 77, Training time: 159.20s, Loss: 84.8290
# Evaluate current model:
#  Epoch: 77, Validation time: 32.98s
#  Loss: 84.8290:
#  Recall@20: 0.1128
#  NDCG@20: 0.2461
# Epoch: 78, Training time: 159.25s, Loss: 83.4920
# Evaluate current model:
#  Epoch: 78, Validation time: 32.79s
#  Loss: 83.4920:
#  Recall@20: 0.1139
#  NDCG@20: 0.2457
# Epoch: 79, Training time: 159.29s, Loss: 82.6159
# Evaluate current model:
#  Epoch: 79, Validation time: 33.02s
#  Loss: 82.6159:
#  Recall@20: 0.1135
#  NDCG@20: 0.2455
# Epoch: 80, Training time: 159.25s, Loss: 81.0959
# Evaluate current model:
#  Epoch: 80, Validation time: 33.47s
#  Loss: 81.0959:
#  Recall@20: 0.1140
#  NDCG@20: 0.2463
# Epoch: 81, Training time: 159.31s, Loss: 80.4355
# Evaluate current model:
#  Epoch: 81, Validation time: 33.32s
#  Loss: 80.4355:
#  Recall@20: 0.1138
#  NDCG@20: 0.2459
# Epoch: 82, Training time: 159.23s, Loss: 79.6193
# Evaluate current model:
#  Epoch: 82, Validation time: 32.91s
#  Loss: 79.6193:
#  Recall@20: 0.1146
#  NDCG@20: 0.2475
# Epoch: 83, Training time: 159.23s, Loss: 77.9165
# Evaluate current model:
#  Epoch: 83, Validation time: 33.18s
#  Loss: 77.9165:
#  Recall@20: 0.1149
#  NDCG@20: 0.2474
# Epoch: 84, Training time: 159.33s, Loss: 77.6860
# Evaluate current model:
#  Epoch: 84, Validation time: 33.96s
#  Loss: 77.6860:
#  Recall@20: 0.1148
#  NDCG@20: 0.2476
# Epoch: 85, Training time: 159.28s, Loss: 76.2988
# Evaluate current model:
#  Epoch: 85, Validation time: 33.88s
#  Loss: 76.2988:
#  Recall@20: 0.1161
#  NDCG@20: 0.2480
# Epoch: 86, Training time: 159.90s, Loss: 75.1918
# Evaluate current model:
#  Epoch: 86, Validation time: 33.53s
#  Loss: 75.1918:
#  Recall@20: 0.1159
#  NDCG@20: 0.2491
# Epoch: 87, Training time: 161.43s, Loss: 73.8959
# Evaluate current model:
#  Epoch: 87, Validation time: 33.12s
#  Loss: 73.8959:
#  Recall@20: 0.1161
#  NDCG@20: 0.2495
# Epoch: 88, Training time: 159.46s, Loss: 72.8001
# Evaluate current model:
#  Epoch: 88, Validation time: 32.93s
#  Loss: 72.8001:
#  Recall@20: 0.1163
#  NDCG@20: 0.2497
# Epoch: 89, Training time: 159.21s, Loss: 72.3301
# Evaluate current model:
#  Epoch: 89, Validation time: 33.13s
#  Loss: 72.3301:
#  Recall@20: 0.1165
#  NDCG@20: 0.2507
# Epoch: 90, Training time: 159.21s, Loss: 71.4904
# Evaluate current model:
#  Epoch: 90, Validation time: 32.95s
#  Loss: 71.4904:
#  Recall@20: 0.1161
#  NDCG@20: 0.2499
# Epoch: 91, Training time: 159.30s, Loss: 70.7125
# Evaluate current model:
#  Epoch: 91, Validation time: 33.03s
#  Loss: 70.7125:
#  Recall@20: 0.1169
#  NDCG@20: 0.2497
# Epoch: 92, Training time: 159.30s, Loss: 69.6352
# Evaluate current model:
#  Epoch: 92, Validation time: 33.23s
#  Loss: 69.6352:
#  Recall@20: 0.1171
#  NDCG@20: 0.2500
# Epoch: 93, Training time: 159.25s, Loss: 68.6566
# Evaluate current model:
#  Epoch: 93, Validation time: 32.80s
#  Loss: 68.6566:
#  Recall@20: 0.1172
#  NDCG@20: 0.2507
# Epoch: 94, Training time: 159.25s, Loss: 67.8299
# Evaluate current model:
#  Epoch: 94, Validation time: 33.09s
#  Loss: 67.8299:
#  Recall@20: 0.1181
#  NDCG@20: 0.2511
# Epoch: 95, Training time: 159.22s, Loss: 67.2140
# Evaluate current model:
#  Epoch: 95, Validation time: 33.08s
#  Loss: 67.2140:
#  Recall@20: 0.1179
#  NDCG@20: 0.2517
# Epoch: 96, Training time: 159.29s, Loss: 66.1078
# Evaluate current model:
#  Epoch: 96, Validation time: 32.87s
#  Loss: 66.1078:
#  Recall@20: 0.1177
#  NDCG@20: 0.2518
# Epoch: 97, Training time: 159.23s, Loss: 65.5152
# Evaluate current model:
#  Epoch: 97, Validation time: 33.08s
#  Loss: 65.5152:
#  Recall@20: 0.1183
#  NDCG@20: 0.2523
# Epoch: 98, Training time: 159.22s, Loss: 64.8680
# Evaluate current model:
#  Epoch: 98, Validation time: 32.81s
#  Loss: 64.8680:
#  Recall@20: 0.1181
#  NDCG@20: 0.2533
# Epoch: 99, Training time: 159.21s, Loss: 63.8081
# Evaluate current model:
#  Epoch: 99, Validation time: 32.89s
#  Loss: 63.8081:
#  Recall@20: 0.1188
#  NDCG@20: 0.2532
# Epoch: 100, Training time: 159.27s, Loss: 63.4699
# Evaluate current model:
#  Epoch: 100, Validation time: 32.98s
#  Loss: 63.4699:
#  Recall@20: 0.1193
#  NDCG@20: 0.2541
# Epoch: 101, Training time: 159.27s, Loss: 62.7476
# Evaluate current model:
#  Epoch: 101, Validation time: 32.88s
#  Loss: 62.7476:
#  Recall@20: 0.1188
#  NDCG@20: 0.2537
# Epoch: 102, Training time: 159.23s, Loss: 61.9718
# Evaluate current model:
#  Epoch: 102, Validation time: 33.22s
#  Loss: 61.9718:
#  Recall@20: 0.1192
#  NDCG@20: 0.2548
# Epoch: 103, Training time: 159.30s, Loss: 61.0971
# Evaluate current model:
#  Epoch: 103, Validation time: 33.90s
#  Loss: 61.0971:
#  Recall@20: 0.1194
#  NDCG@20: 0.2547
# Epoch: 104, Training time: 159.21s, Loss: 60.2353
# Evaluate current model:
#  Epoch: 104, Validation time: 33.47s
#  Loss: 60.2353:
#  Recall@20: 0.1194
#  NDCG@20: 0.2553
# Epoch: 105, Training time: 159.25s, Loss: 59.5696
# Evaluate current model:
#  Epoch: 105, Validation time: 32.96s
#  Loss: 59.5696:
#  Recall@20: 0.1198
#  NDCG@20: 0.2549
# Epoch: 106, Training time: 159.28s, Loss: 58.7839
# Evaluate current model:
#  Epoch: 106, Validation time: 33.08s
#  Loss: 58.7839:
#  Recall@20: 0.1201
#  NDCG@20: 0.2556
# Epoch: 107, Training time: 159.21s, Loss: 58.2764
# Evaluate current model:
#  Epoch: 107, Validation time: 33.27s
#  Loss: 58.2764:
#  Recall@20: 0.1204
#  NDCG@20: 0.2564
# Epoch: 108, Training time: 159.30s, Loss: 57.8062
# Evaluate current model:
#  Epoch: 108, Validation time: 33.50s
#  Loss: 57.8062:
#  Recall@20: 0.1204
#  NDCG@20: 0.2550
# Epoch: 109, Training time: 159.25s, Loss: 57.2467
# Evaluate current model:
#  Epoch: 109, Validation time: 33.99s
#  Loss: 57.2467:
#  Recall@20: 0.1206
#  NDCG@20: 0.2553
# Epoch: 110, Training time: 159.25s, Loss: 56.6992
# Evaluate current model:
#  Epoch: 110, Validation time: 33.25s
#  Loss: 56.6992:
#  Recall@20: 0.1207
#  NDCG@20: 0.2568
# Epoch: 111, Training time: 159.27s, Loss: 56.2754
# Evaluate current model:
#  Epoch: 111, Validation time: 33.32s
#  Loss: 56.2754:
#  Recall@20: 0.1210
#  NDCG@20: 0.2565
# Epoch: 112, Training time: 159.17s, Loss: 55.3342
# Evaluate current model:
#  Epoch: 112, Validation time: 33.57s
#  Loss: 55.3342:
#  Recall@20: 0.1211
#  NDCG@20: 0.2569
# Epoch: 113, Training time: 159.33s, Loss: 54.4653
# Evaluate current model:
#  Epoch: 113, Validation time: 33.68s
#  Loss: 54.4653:
#  Recall@20: 0.1212
#  NDCG@20: 0.2580
# Epoch: 114, Training time: 159.21s, Loss: 54.3773
# Evaluate current model:
#  Epoch: 114, Validation time: 33.82s
#  Loss: 54.3773:
#  Recall@20: 0.1211
#  NDCG@20: 0.2573
# Epoch: 115, Training time: 159.29s, Loss: 53.5664
# Evaluate current model:
#  Epoch: 115, Validation time: 33.02s
#  Loss: 53.5664:
#  Recall@20: 0.1217
#  NDCG@20: 0.2589
# Epoch: 116, Training time: 159.34s, Loss: 53.2001
# Evaluate current model:
#  Epoch: 116, Validation time: 33.12s
#  Loss: 53.2001:
#  Recall@20: 0.1215
#  NDCG@20: 0.2586
# Epoch: 117, Training time: 159.20s, Loss: 52.2720
# Evaluate current model:
#  Epoch: 117, Validation time: 33.24s
#  Loss: 52.2720:
#  Recall@20: 0.1217
#  NDCG@20: 0.2591
# Epoch: 118, Training time: 159.21s, Loss: 52.1751
# Evaluate current model:
#  Epoch: 118, Validation time: 33.58s
#  Loss: 52.1751:
#  Recall@20: 0.1221
#  NDCG@20: 0.2583
# Epoch: 119, Training time: 159.25s, Loss: 51.4451
# Evaluate current model:
#  Epoch: 119, Validation time: 33.13s
#  Loss: 51.4451:
#  Recall@20: 0.1221
#  NDCG@20: 0.2594
# Epoch: 120, Training time: 159.16s, Loss: 51.0382
# Evaluate current model:
#  Epoch: 120, Validation time: 33.20s
#  Loss: 51.0382:
#  Recall@20: 0.1225
#  NDCG@20: 0.2601
# Epoch: 121, Training time: 163.94s, Loss: 50.4329
# Evaluate current model:
#  Epoch: 121, Validation time: 33.41s
#  Loss: 50.4329:
#  Recall@20: 0.1168
#  NDCG@20: 0.2490
# Epoch: 122, Training time: 163.93s, Loss: 50.1522
# Evaluate current model:
#  Epoch: 122, Validation time: 33.61s
#  Loss: 50.1522:
#  Recall@20: 0.1190
#  NDCG@20: 0.2524
# Epoch: 123, Training time: 163.99s, Loss: 49.5359
# Evaluate current model:
#  Epoch: 123, Validation time: 33.39s
#  Loss: 49.5359:
#  Recall@20: 0.1184
#  NDCG@20: 0.2524
# Epoch: 124, Training time: 163.96s, Loss: 49.2022
# Evaluate current model:
#  Epoch: 124, Validation time: 33.28s
#  Loss: 49.2022:
#  Recall@20: 0.1183
#  NDCG@20: 0.2520
# Epoch: 125, Training time: 164.08s, Loss: 48.6673
# Evaluate current model:
#  Epoch: 125, Validation time: 33.82s
#  Loss: 48.6673:
#  Recall@20: 0.1185
#  NDCG@20: 0.2511
# Epoch: 126, Training time: 163.99s, Loss: 48.1836
# Evaluate current model:
#  Epoch: 126, Validation time: 33.89s
#  Loss: 48.1836:
#  Recall@20: 0.1175
#  NDCG@20: 0.2504
# Epoch: 127, Training time: 163.93s, Loss: 47.6382
# Evaluate current model:
#  Epoch: 127, Validation time: 34.19s
#  Loss: 47.6382:
#  Recall@20: 0.1181
#  NDCG@20: 0.2508
# Epoch: 128, Training time: 163.98s, Loss: 47.4323
# Evaluate current model:
#  Epoch: 128, Validation time: 33.08s
#  Loss: 47.4323:
#  Recall@20: 0.1181
#  NDCG@20: 0.2543
# Epoch: 129, Training time: 164.00s, Loss: 46.9366
# Evaluate current model:
#  Epoch: 129, Validation time: 33.22s
#  Loss: 46.9366:
#  Recall@20: 0.1179
#  NDCG@20: 0.2520
# Epoch: 130, Training time: 163.94s, Loss: 46.5775
# Evaluate current model:
#  Epoch: 130, Validation time: 33.18s
#  Loss: 46.5775:
#  Recall@20: 0.1189
#  NDCG@20: 0.2550
# Epoch: 131, Training time: 164.06s, Loss: 46.0881
# Evaluate current model:
#  Epoch: 131, Validation time: 33.82s
#  Loss: 46.0881:
#  Recall@20: 0.1203
#  NDCG@20: 0.2548
# Epoch: 132, Training time: 163.94s, Loss: 45.7676
# Evaluate current model:
#  Epoch: 132, Validation time: 33.79s
#  Loss: 45.7676:
#  Recall@20: 0.1190
#  NDCG@20: 0.2541
# Epoch: 133, Training time: 164.10s, Loss: 45.1714
# Evaluate current model:
#  Epoch: 133, Validation time: 33.29s
#  Loss: 45.1714:
#  Recall@20: 0.1185
#  NDCG@20: 0.2539
# Epoch: 134, Training time: 164.01s, Loss: 45.0733
# Evaluate current model:
#  Epoch: 134, Validation time: 33.09s
#  Loss: 45.0733:
#  Recall@20: 0.1197
#  NDCG@20: 0.2543
# Epoch: 135, Training time: 164.02s, Loss: 44.2589
# Evaluate current model:
#  Epoch: 135, Validation time: 33.05s
#  Loss: 44.2589:
#  Recall@20: 0.1188
#  NDCG@20: 0.2518
# Epoch: 136, Training time: 164.03s, Loss: 43.9097
# Evaluate current model:
#  Epoch: 136, Validation time: 33.26s
#  Loss: 43.9097:
#  Recall@20: 0.1190
#  NDCG@20: 0.2521
# Epoch: 137, Training time: 164.02s, Loss: 43.5440
# Evaluate current model:
#  Epoch: 137, Validation time: 33.22s
#  Loss: 43.5440:
#  Recall@20: 0.1190
#  NDCG@20: 0.2540
# Epoch: 138, Training time: 164.04s, Loss: 43.4164
# Evaluate current model:
#  Epoch: 138, Validation time: 32.96s
#  Loss: 43.4164:
#  Recall@20: 0.1210
#  NDCG@20: 0.2559
# Epoch: 139, Training time: 163.96s, Loss: 43.0570
# Evaluate current model:
#  Epoch: 139, Validation time: 32.85s
#  Loss: 43.0570:
#  Recall@20: 0.1194
#  NDCG@20: 0.2535
# Epoch: 140, Training time: 163.98s, Loss: 42.8427
# Evaluate current model:
#  Epoch: 140, Validation time: 33.15s
#  Loss: 42.8427:
#  Recall@20: 0.1196
#  NDCG@20: 0.2559
# Epoch: 141, Training time: 164.05s, Loss: 41.8180
# Evaluate current model:
#  Epoch: 141, Validation time: 33.00s
#  Loss: 41.8180:
#  Recall@20: 0.1202
#  NDCG@20: 0.2544
# Epoch: 142, Training time: 163.97s, Loss: 41.9360
# Evaluate current model:
#  Epoch: 142, Validation time: 33.12s
#  Loss: 41.9360:
#  Recall@20: 0.1201
#  NDCG@20: 0.2570
# Epoch: 143, Training time: 164.15s, Loss: 41.4900
# Evaluate current model:
#  Epoch: 143, Validation time: 32.84s
#  Loss: 41.4900:
#  Recall@20: 0.1206
#  NDCG@20: 0.2534
# Epoch: 144, Training time: 163.99s, Loss: 41.5102
# Evaluate current model:
#  Epoch: 144, Validation time: 33.18s
#  Loss: 41.5102:
#  Recall@20: 0.1198
#  NDCG@20: 0.2525
# Epoch: 145, Training time: 163.94s, Loss: 41.1162
# Evaluate current model:
#  Epoch: 145, Validation time: 33.35s
#  Loss: 41.1162:
#  Recall@20: 0.1206
#  NDCG@20: 0.2569
# Epoch: 146, Training time: 164.03s, Loss: 40.5867
# Evaluate current model:
#  Epoch: 146, Validation time: 33.66s
#  Loss: 40.5867:
#  Recall@20: 0.1204
#  NDCG@20: 0.2547
# Epoch: 147, Training time: 164.05s, Loss: 40.1108
# Evaluate current model:
#  Epoch: 147, Validation time: 32.92s
#  Loss: 40.1108:
#  Recall@20: 0.1195
#  NDCG@20: 0.2547
# Epoch: 148, Training time: 163.93s, Loss: 40.0915
# Evaluate current model:
#  Epoch: 148, Validation time: 33.06s
#  Loss: 40.0915:
#  Recall@20: 0.1211
#  NDCG@20: 0.2569
# Epoch: 149, Training time: 164.04s, Loss: 39.7304
# Evaluate current model:
#  Epoch: 149, Validation time: 32.99s
#  Loss: 39.7304:
#  Recall@20: 0.1200
#  NDCG@20: 0.2549
# Epoch: 150, Training time: 163.96s, Loss: 39.2524
# Evaluate current model:
#  Epoch: 150, Validation time: 33.12s
#  Loss: 39.2524:
#  Recall@20: 0.1213
#  NDCG@20: 0.2556
# Epoch: 151, Training time: 163.93s, Loss: 39.2890
# Evaluate current model:
#  Epoch: 151, Validation time: 33.01s
#  Loss: 39.2890:
#  Recall@20: 0.1207
#  NDCG@20: 0.2531
# Epoch: 152, Training time: 163.95s, Loss: 38.7450
# Evaluate current model:
#  Epoch: 152, Validation time: 33.25s
#  Loss: 38.7450:
#  Recall@20: 0.1230
#  NDCG@20: 0.2577
# Epoch: 153, Training time: 163.94s, Loss: 38.3682
# Evaluate current model:
#  Epoch: 153, Validation time: 33.16s
#  Loss: 38.3682:
#  Recall@20: 0.1214
#  NDCG@20: 0.2531
# Epoch: 154, Training time: 163.99s, Loss: 38.0129
# Evaluate current model:
#  Epoch: 154, Validation time: 33.36s
#  Loss: 38.0129:
#  Recall@20: 0.1191
#  NDCG@20: 0.2538
# Epoch: 155, Training time: 164.00s, Loss: 38.1094
# Evaluate current model:
#  Epoch: 155, Validation time: 33.39s
#  Loss: 38.1094:
#  Recall@20: 0.1214
#  NDCG@20: 0.2580
# Epoch: 156, Training time: 163.95s, Loss: 37.5740
# Evaluate current model:
#  Epoch: 156, Validation time: 33.07s
#  Loss: 37.5740:
#  Recall@20: 0.1224
#  NDCG@20: 0.2575
# Epoch: 157, Training time: 163.97s, Loss: 37.1948
# Evaluate current model:
#  Epoch: 157, Validation time: 33.11s
#  Loss: 37.1948:
#  Recall@20: 0.1216
#  NDCG@20: 0.2538
# Epoch: 158, Training time: 163.99s, Loss: 37.0590
# Evaluate current model:
#  Epoch: 158, Validation time: 33.60s
#  Loss: 37.0590:
#  Recall@20: 0.1205
#  NDCG@20: 0.2545
# Epoch: 159, Training time: 163.92s, Loss: 36.7869
# Evaluate current model:
#  Epoch: 159, Validation time: 33.70s
#  Loss: 36.7869:
#  Recall@20: 0.1217
#  NDCG@20: 0.2532
# Epoch: 160, Training time: 164.39s, Loss: 36.5866
# Evaluate current model:
#  Epoch: 160, Validation time: 33.59s
#  Loss: 36.5866:
#  Recall@20: 0.1222
#  NDCG@20: 0.2587
# Epoch: 161, Training time: 163.98s, Loss: 36.1720
# Evaluate current model:
#  Epoch: 161, Validation time: 34.37s
#  Loss: 36.1720:
#  Recall@20: 0.1222
#  NDCG@20: 0.2563
# Epoch: 162, Training time: 163.98s, Loss: 35.8251
# Evaluate current model:
#  Epoch: 162, Validation time: 33.41s
#  Loss: 35.8251:
#  Recall@20: 0.1227
#  NDCG@20: 0.2580
# Epoch: 163, Training time: 163.93s, Loss: 35.5726
# Evaluate current model:
#  Epoch: 163, Validation time: 33.82s
#  Loss: 35.5726:
#  Recall@20: 0.1224
#  NDCG@20: 0.2540
# Epoch: 164, Training time: 163.96s, Loss: 35.1821
# Evaluate current model:
#  Epoch: 164, Validation time: 34.37s
#  Loss: 35.1821:
#  Recall@20: 0.1233
#  NDCG@20: 0.2587
# Epoch: 165, Training time: 163.97s, Loss: 35.1951
# Evaluate current model:
#  Epoch: 165, Validation time: 33.27s
#  Loss: 35.1951:
#  Recall@20: 0.1231
#  NDCG@20: 0.2549
# Epoch: 166, Training time: 164.00s, Loss: 35.0859
# Evaluate current model:
#  Epoch: 166, Validation time: 33.60s
#  Loss: 35.0859:
#  Recall@20: 0.1240
#  NDCG@20: 0.2590
# Epoch: 167, Training time: 163.83s, Loss: 34.5731
# Evaluate current model:
#  Epoch: 167, Validation time: 33.82s
#  Loss: 34.5731:
#  Recall@20: 0.1223
#  NDCG@20: 0.2584
# Epoch: 168, Training time: 164.10s, Loss: 34.6600
# Evaluate current model:
#  Epoch: 168, Validation time: 33.52s
#  Loss: 34.6600:
#  Recall@20: 0.1220
#  NDCG@20: 0.2553
# Epoch: 169, Training time: 163.99s, Loss: 34.3240
# Evaluate current model:
#  Epoch: 169, Validation time: 33.68s
#  Loss: 34.3240:
#  Recall@20: 0.1224
#  NDCG@20: 0.2571
# Epoch: 170, Training time: 164.04s, Loss: 34.0472
# Evaluate current model:
#  Epoch: 170, Validation time: 33.88s
#  Loss: 34.0472:
#  Recall@20: 0.1218
#  NDCG@20: 0.2562
# Epoch: 171, Training time: 163.94s, Loss: 33.7996
# Evaluate current model:
#  Epoch: 171, Validation time: 33.58s
#  Loss: 33.7996:
#  Recall@20: 0.1230
#  NDCG@20: 0.2565
# Epoch: 172, Training time: 163.94s, Loss: 33.5973
# Evaluate current model:
#  Epoch: 172, Validation time: 33.69s
#  Loss: 33.5973:
#  Recall@20: 0.1224
#  NDCG@20: 0.2586
# Epoch: 173, Training time: 163.95s, Loss: 33.1435
# Evaluate current model:
#  Epoch: 173, Validation time: 33.51s
#  Loss: 33.1435:
#  Recall@20: 0.1226
#  NDCG@20: 0.2539
# Epoch: 174, Training time: 163.99s, Loss: 33.0287
# Evaluate current model:
#  Epoch: 174, Validation time: 33.00s
#  Loss: 33.0287:
#  Recall@20: 0.1224
#  NDCG@20: 0.2558
# Epoch: 175, Training time: 163.92s, Loss: 33.0914
# Evaluate current model:
#  Epoch: 175, Validation time: 33.35s
#  Loss: 33.0914:
#  Recall@20: 0.1237
#  NDCG@20: 0.2600
# Epoch: 176, Training time: 163.98s, Loss: 32.7862
# Evaluate current model:
#  Epoch: 176, Validation time: 33.42s
#  Loss: 32.7862:
#  Recall@20: 0.1246
#  NDCG@20: 0.2585
# Epoch: 177, Training time: 164.05s, Loss: 32.5748
# Evaluate current model:
#  Epoch: 177, Validation time: 33.49s
#  Loss: 32.5748:
#  Recall@20: 0.1226
#  NDCG@20: 0.2556
# Epoch: 178, Training time: 163.97s, Loss: 32.3516
# Evaluate current model:
#  Epoch: 178, Validation time: 33.71s
#  Loss: 32.3516:
#  Recall@20: 0.1218
#  NDCG@20: 0.2565
# Epoch: 179, Training time: 163.93s, Loss: 32.0664
# Evaluate current model:
#  Epoch: 179, Validation time: 33.36s
#  Loss: 32.0664:
#  Recall@20: 0.1231
#  NDCG@20: 0.2570
# Epoch: 180, Training time: 164.04s, Loss: 31.9848
# Evaluate current model:
#  Epoch: 180, Validation time: 33.59s
#  Loss: 31.9848:
#  Recall@20: 0.1238
#  NDCG@20: 0.2584
# Epoch: 181, Training time: 164.02s, Loss: 31.6802
# Evaluate current model:
#  Epoch: 181, Validation time: 33.27s
#  Loss: 31.6802:
#  Recall@20: 0.1232
#  NDCG@20: 0.2557
# Epoch: 182, Training time: 163.90s, Loss: 31.6362
# Evaluate current model:
#  Epoch: 182, Validation time: 33.60s
#  Loss: 31.6362:
#  Recall@20: 0.1239
#  NDCG@20: 0.2543
# Epoch: 183, Training time: 164.17s, Loss: 31.3309
# Evaluate current model:
#  Epoch: 183, Validation time: 32.98s
#  Loss: 31.3309:
#  Recall@20: 0.1240
#  NDCG@20: 0.2583
# Epoch: 184, Training time: 164.00s, Loss: 30.9047
# Evaluate current model:
#  Epoch: 184, Validation time: 33.17s
#  Loss: 30.9047:
#  Recall@20: 0.1227
#  NDCG@20: 0.2540
# Epoch: 185, Training time: 164.02s, Loss: 30.9544
# Evaluate current model:
#  Epoch: 185, Validation time: 33.10s
#  Loss: 30.9544:
#  Recall@20: 0.1250
#  NDCG@20: 0.2615
# Epoch: 186, Training time: 164.03s, Loss: 30.8797
# Evaluate current model:
#  Epoch: 186, Validation time: 33.26s
#  Loss: 30.8797:
#  Recall@20: 0.1251
#  NDCG@20: 0.2596
# Epoch: 187, Training time: 163.99s, Loss: 30.7657
# Evaluate current model:
#  Epoch: 187, Validation time: 33.45s
#  Loss: 30.7657:
#  Recall@20: 0.1235
#  NDCG@20: 0.2563
# Epoch: 188, Training time: 164.07s, Loss: 30.3065
# Evaluate current model:
#  Epoch: 188, Validation time: 32.75s
#  Loss: 30.3065:
#  Recall@20: 0.1241
#  NDCG@20: 0.2586
# Epoch: 189, Training time: 164.03s, Loss: 30.3217
# Evaluate current model:
#  Epoch: 189, Validation time: 32.82s
#  Loss: 30.3217:
#  Recall@20: 0.1242
#  NDCG@20: 0.2597
# Epoch: 190, Training time: 164.03s, Loss: 30.0207
# Evaluate current model:
#  Epoch: 190, Validation time: 32.85s
#  Loss: 30.0207:
#  Recall@20: 0.1250
#  NDCG@20: 0.2590
# Epoch: 191, Training time: 164.02s, Loss: 29.7850
# Evaluate current model:
#  Epoch: 191, Validation time: 32.92s
#  Loss: 29.7850:
#  Recall@20: 0.1245
#  NDCG@20: 0.2545
# Epoch: 192, Training time: 164.08s, Loss: 29.8645
# Evaluate current model:
#  Epoch: 192, Validation time: 32.83s
#  Loss: 29.8645:
#  Recall@20: 0.1238
#  NDCG@20: 0.2546
# Epoch: 193, Training time: 164.06s, Loss: 29.1941
# Evaluate current model:
#  Epoch: 193, Validation time: 32.92s
#  Loss: 29.1941:
#  Recall@20: 0.1249
#  NDCG@20: 0.2548
# Epoch: 194, Training time: 163.98s, Loss: 29.4519
# Evaluate current model:
#  Epoch: 194, Validation time: 32.96s
#  Loss: 29.4519:
#  Recall@20: 0.1248
#  NDCG@20: 0.2583
# Epoch: 195, Training time: 164.13s, Loss: 29.0823
# Evaluate current model:
#  Epoch: 195, Validation time: 33.03s
#  Loss: 29.0823:
#  Recall@20: 0.1255
#  NDCG@20: 0.2592
# Epoch: 196, Training time: 164.07s, Loss: 29.1735
# Evaluate current model:
#  Epoch: 196, Validation time: 33.42s
#  Loss: 29.1735:
#  Recall@20: 0.1254
#  NDCG@20: 0.2591
# Epoch: 197, Training time: 164.30s, Loss: 29.1208
# Evaluate current model:
#  Epoch: 197, Validation time: 33.50s
#  Loss: 29.1208:
#  Recall@20: 0.1249
#  NDCG@20: 0.2591
# Epoch: 198, Training time: 164.13s, Loss: 28.8081
# Evaluate current model:
#  Epoch: 198, Validation time: 33.70s
#  Loss: 28.8081:
#  Recall@20: 0.1263
#  NDCG@20: 0.2571
# Epoch: 199, Training time: 163.97s, Loss: 28.4467
# Evaluate current model:
#  Epoch: 199, Validation time: 33.45s
#  Loss: 28.4467:
#  Recall@20: 0.1257
#  NDCG@20: 0.2574
